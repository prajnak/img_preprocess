# %%
# Install a pip package in the current Jupyter kernel
import sys
# !{sys.executable} -m pip install -U scikit-learn
# Out:
# Collecting scikit-learn
#   Using cached scikit_learn-0.19.1-cp35-cp35m-manylinux1_x86_64.whl
# Installing collected packages: scikit-learn
# Successfully installed scikit-learn-0.19.1
# You are using pip version 8.1.2, however version 9.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import boto3
import botocore
BUCKET_NAME = "nanonets-platform-task"

# %%
def get_files():
    s3 = boto3.client('s3', 'us-west-2')
    paginator = s3.get_paginator('list_objects')
    page_iterator = paginator.paginate(Bucket = BUCKET_NAME)
    images = []
    for page in page_iterator:
        for a in page['Contents']:
            category, filename = a['Key'].split('/', 1)
            if category == 'processed': # this is where we store processed images.
                continue
            if a['Key'].endswith('jpg'):
                image_format = 'jpg'
            elif a['Key'].endswith('png'):
                image_format = 'png'
            else:
                image_format = 'unknown'
            images.append({'category': category, 'name': filename, 's3key': a['Key'], 'format': image_format})
            
    return images

# %%
images = get_files()

# %%
categories = {image['category'] for image in images}
categories
# Out:
# {'daisy', 'dandelion', 'roses', 'sunflowers'}

# %%
len(images)
# Out:
# 2598

# %%
[a for a in images if a['format'] == 'unknown']
# Out:
# [{'category': 'daisy',
#   'format': 'unknown',
#   'name': 'LICENSE.txt',
#   's3key': 'daisy/LICENSE.txt'}]

# %%
import pandas as pd

images_df = pd.DataFrame(images)
pp = images_df.head()

# %%
images_df = images_df[images_df['format'] != 'unknown'] # drop unknown file types

# %%
images_df.shape
# Out:
# (2597, 6)

# %%
from io import BytesIO
from PIL import Image
import imghdr

s3 = boto3.client('s3', 'us-west-2')
TARGET_SIZE = (300, 300)
TARGET_COLORS = (255,255,255)

def download_image(row):
    string_io = BytesIO()
    s3.download_fileobj(Bucket=BUCKET_NAME, Key=row['s3key'], Fileobj=string_io)
    return string_io

def get_image_format(dat):
    return imghdr.what(None, dat.getvalue())
        
def transform_image(row):
    img_format = get_image_format(row['rawdata'])
    if img_format == None:
        return "Invalid"
    img_dat = Image.open(row['rawdata'])
    if img_format != 'jpeg':
        rgb_img_dat = img_dat.convert('RGB')
        resized = rgb_img_dat.resize(TARGET_SIZE)
    else:
        resized = img_dat.resize(TARGET_SIZE)
    out_bytes = BytesIO()
    resized.save(out_bytes, format='jpeg')
    out_bytes.seek(0)
    return out_bytes

# %%
images_df['rawdata'] = images_df.apply(download_image, axis=1) # this will take a while

# %%
images_df['resized'] = images_df.apply(transform_image, axis=1)

# %%
images_df.shape
images_df[images_df['resized'] == "Invalid"].shape # no invalid images
# Out:
# (0, 6)

# %%
import numpy as np

# %%
train, validate, test = np.split(images_df.sample(frac=1), [int(.7*len(images_df)), int(.9*len(images_df))])

# %%
(validate.shape, test.shape, train.shape)
# Out:
# ((520, 6), (260, 6), (1817, 6))

# %%
def upload_df_to_s3(df, split=""):
    print('Uploading to bucket:{0}'.format(BUCKET_NAME))
    for index, row in df.iterrows():
        category_tracker[row['category']] += 1
        s3key = 'processed/{0}/{1}/img{2}.jpg'.format(row['category'], 
                                                      split, 
                                                      category_tracker[row['category']])
        print('Uploading file:{0}'.format(s3key))
        s3.upload_fileobj(Bucket=BUCKET_NAME, Fileobj=row['resized'], Key=s3key, Callback=lambda x: print(x))

# %%
category_tracker = dict(zip(categories, [0]*len(categories)))
upload_df_to_s3(train, "train")
# Out:
# Uploading to bucket:nanonets-platform-task
# Uploading file:processed/dandelion/train/img1.jpg
# 22790
# Uploading file:processed/roses/train/img1.jpg
# 22316
# Uploading file:processed/dandelion/train/img2.jpg
# 16454
# Uploading file:processed/roses/train/img2.jpg
# 13574
# Uploading file:processed/dandelion/train/img3.jpg
# 10552
# Uploading file:processed/dandelion/train/img4.jpg
# 12050
# Uploading file:processed/dandelion/train/img5.jpg
# 12594
# Uploading file:processed/sunflowers/train/img1.jpg
# 25863
# Uploading file:processed/roses/train/img3.jpg
# 17270
# Uploading file:processed/dandelion/train/img6.jpg
# 15092
# Uploading file:processed/dandelion/train/img7.jpg
# 27793
# Uploading file:processed/dandelion/train/img8.jpg
# 17113
# Uploading file:processed/dandelion/train/img9.jpg
# 17734
# Uploading file:processed/daisy/train/img1.jpg
# 8197
# Uploading file:processed/dandelion/train/img10.jpg
# 17412
# Uploading file:processed/dandelion/train/img11.jpg
# 12099
# Uploading file:processed/roses/train/img4.jpg
# 26155
# Uploading file:processed/dandelion/train/img12.jpg
# 18159
# Uploading file:processed/roses/train/img5.jpg
# 17617
# Uploading file:processed/dandelion/train/img13.jpg
# 12727
# Uploading file:processed/roses/train/img6.jpg
# 20364
# Uploading file:processed/dandelion/train/img14.jpg
# 11548
# Uploading file:processed/daisy/train/img2.jpg
# 9553
# Uploading file:processed/dandelion/train/img15.jpg
# 19759
# Uploading file:processed/dandelion/train/img16.jpg
# 19873
# Uploading file:processed/daisy/train/img3.jpg
# 37909
# Uploading file:processed/roses/train/img7.jpg
# 12314
# Uploading file:processed/daisy/train/img4.jpg
# 18355
# Uploading file:processed/dandelion/train/img17.jpg
# 9312
# Uploading file:processed/daisy/train/img5.jpg
# 10897
# Uploading file:processed/sunflowers/train/img2.jpg
# 22191
# Uploading file:processed/dandelion/train/img18.jpg
# 10032
# Uploading file:processed/daisy/train/img6.jpg
# 14332
# Uploading file:processed/daisy/train/img7.jpg
# 20371
# Uploading file:processed/roses/train/img8.jpg
# 10924
# Uploading file:processed/roses/train/img9.jpg
# 18265
# Uploading file:processed/dandelion/train/img19.jpg
# 19155
# Uploading file:processed/daisy/train/img8.jpg
# 14533
# Uploading file:processed/dandelion/train/img20.jpg
# 14951
# Uploading file:processed/roses/train/img10.jpg
# 16820
# Uploading file:processed/dandelion/train/img21.jpg
# 19829
# Uploading file:processed/sunflowers/train/img3.jpg
# 32933
# Uploading file:processed/dandelion/train/img22.jpg
# 23776
# Uploading file:processed/dandelion/train/img23.jpg
# 10513
# Uploading file:processed/daisy/train/img9.jpg
# 25013
# Uploading file:processed/roses/train/img11.jpg
# 24460
# Uploading file:processed/daisy/train/img10.jpg
# 10792
# Uploading file:processed/roses/train/img12.jpg
# 20301
# Uploading file:processed/daisy/train/img11.jpg
# 18411
# Uploading file:processed/sunflowers/train/img4.jpg
# 26958
# Uploading file:processed/roses/train/img13.jpg
# 24393
# Uploading file:processed/daisy/train/img12.jpg
# 12346
# Uploading file:processed/roses/train/img14.jpg
# 31396
# Uploading file:processed/roses/train/img15.jpg
# 30950
# Uploading file:processed/roses/train/img16.jpg
# 12047
# Uploading file:processed/roses/train/img17.jpg
# 40033
# Uploading file:processed/roses/train/img18.jpg
# 39937
# Uploading file:processed/sunflowers/train/img5.jpg
# 31300
# Uploading file:processed/roses/train/img19.jpg
# 18480
# Uploading file:processed/daisy/train/img13.jpg
# 19667
# Uploading file:processed/sunflowers/train/img6.jpg
# 21322
# Uploading file:processed/dandelion/train/img24.jpg
# 19859
# Uploading file:processed/sunflowers/train/img7.jpg
# 23591
# Uploading file:processed/dandelion/train/img25.jpg
# 16866
# Uploading file:processed/daisy/train/img14.jpg
# 16461
# Uploading file:processed/dandelion/train/img26.jpg
# 14992
# Uploading file:processed/sunflowers/train/img8.jpg
# 26174
# Uploading file:processed/dandelion/train/img27.jpg
# 8078
# Uploading file:processed/dandelion/train/img28.jpg
# 17034
# Uploading file:processed/sunflowers/train/img9.jpg
# 23684
# Uploading file:processed/sunflowers/train/img10.jpg
# 15587
# Uploading file:processed/dandelion/train/img29.jpg
# 18411
# Uploading file:processed/dandelion/train/img30.jpg
# 14813
# Uploading file:processed/roses/train/img20.jpg
# 12805
# Uploading file:processed/roses/train/img21.jpg
# 17220
# Uploading file:processed/roses/train/img22.jpg
# 20444
# Uploading file:processed/sunflowers/train/img11.jpg
# 28259
# Uploading file:processed/dandelion/train/img31.jpg
# 29589
# Uploading file:processed/daisy/train/img15.jpg
# 29426
# Uploading file:processed/roses/train/img23.jpg
# 25343
# Uploading file:processed/roses/train/img24.jpg
# 17477
# Uploading file:processed/sunflowers/train/img12.jpg
# 21304
# Uploading file:processed/dandelion/train/img32.jpg
# 9828
# Uploading file:processed/daisy/train/img16.jpg
# 23950
# Uploading file:processed/sunflowers/train/img13.jpg
# 27429
# Uploading file:processed/dandelion/train/img33.jpg
# 15703
# Uploading file:processed/roses/train/img25.jpg
# 17431
# Uploading file:processed/roses/train/img26.jpg
# 25268
# Uploading file:processed/dandelion/train/img34.jpg
# 15215
# Uploading file:processed/roses/train/img27.jpg
# 13643
# Uploading file:processed/daisy/train/img17.jpg
# 18098
# Uploading file:processed/roses/train/img28.jpg
# 9941
# Uploading file:processed/dandelion/train/img35.jpg
# 16024
# Uploading file:processed/dandelion/train/img36.jpg
# 6706
# Uploading file:processed/dandelion/train/img37.jpg
# 13346
# Uploading file:processed/daisy/train/img18.jpg
# 30785
# Uploading file:processed/sunflowers/train/img14.jpg
# 22387
# Uploading file:processed/dandelion/train/img38.jpg
# 18971
# Uploading file:processed/dandelion/train/img39.jpg
# 10760
# Uploading file:processed/daisy/train/img19.jpg
# 11791
# Uploading file:processed/sunflowers/train/img15.jpg
# 36817
# Uploading file:processed/roses/train/img29.jpg
# 18091
# Uploading file:processed/daisy/train/img20.jpg
# 16302
# Uploading file:processed/daisy/train/img21.jpg
# 20304
# Uploading file:processed/sunflowers/train/img16.jpg
# 15246
# Uploading file:processed/daisy/train/img22.jpg
# 18766
# Uploading file:processed/daisy/train/img23.jpg
# 9413
# Uploading file:processed/roses/train/img30.jpg
# 23751
# Uploading file:processed/dandelion/train/img40.jpg
# 20624
# Uploading file:processed/dandelion/train/img41.jpg
# 19576
# Uploading file:processed/dandelion/train/img42.jpg
# 15896
# Uploading file:processed/sunflowers/train/img17.jpg
# 24096
# Uploading file:processed/dandelion/train/img43.jpg
# 11826
# Uploading file:processed/daisy/train/img24.jpg
# 9565
# Uploading file:processed/dandelion/train/img44.jpg
# 14951
# Uploading file:processed/daisy/train/img25.jpg
# 37386
# Uploading file:processed/daisy/train/img26.jpg
# 9402
# Uploading file:processed/daisy/train/img27.jpg
# 12845
# Uploading file:processed/dandelion/train/img45.jpg
# 14165
# Uploading file:processed/daisy/train/img28.jpg
# 19341
# Uploading file:processed/dandelion/train/img46.jpg
# 16014
# Uploading file:processed/sunflowers/train/img18.jpg
# 27488
# Uploading file:processed/roses/train/img31.jpg
# 43847
# Uploading file:processed/dandelion/train/img47.jpg
# 27004
# Uploading file:processed/dandelion/train/img48.jpg
# 18066
# Uploading file:processed/sunflowers/train/img19.jpg
# 16890
# Uploading file:processed/dandelion/train/img49.jpg
# 20756
# Uploading file:processed/roses/train/img32.jpg
# 17915
# Uploading file:processed/daisy/train/img29.jpg
# 13299
# Uploading file:processed/roses/train/img33.jpg
# 16313
# Uploading file:processed/daisy/train/img30.jpg
# 26092
# Uploading file:processed/roses/train/img34.jpg
# 33611
# Uploading file:processed/dandelion/train/img50.jpg
# 7882
# Uploading file:processed/daisy/train/img31.jpg
# 15084
# Uploading file:processed/roses/train/img35.jpg
# 17388
# Uploading file:processed/sunflowers/train/img20.jpg
# 43254
# Uploading file:processed/sunflowers/train/img21.jpg
# 20323
# Uploading file:processed/roses/train/img36.jpg
# 25190
# Uploading file:processed/roses/train/img37.jpg
# 11133
# Uploading file:processed/daisy/train/img32.jpg
# 20324
# Uploading file:processed/sunflowers/train/img22.jpg
# 37516
# Uploading file:processed/dandelion/train/img51.jpg
# 8228
# Uploading file:processed/sunflowers/train/img23.jpg
# 22133
# Uploading file:processed/daisy/train/img33.jpg
# 18336
# Uploading file:processed/dandelion/train/img52.jpg
# 15394
# Uploading file:processed/dandelion/train/img53.jpg
# 10306
# Uploading file:processed/daisy/train/img34.jpg
# 12341
# Uploading file:processed/roses/train/img38.jpg
# 30351
# Uploading file:processed/dandelion/train/img54.jpg
# 17105
# Uploading file:processed/daisy/train/img35.jpg
# 17216
# Uploading file:processed/roses/train/img39.jpg
# 11798
# Uploading file:processed/dandelion/train/img55.jpg
# 20592
# Uploading file:processed/dandelion/train/img56.jpg
# 19248
# Uploading file:processed/daisy/train/img36.jpg
# 25397
# Uploading file:processed/dandelion/train/img57.jpg
# 23187
# Uploading file:processed/roses/train/img40.jpg
# 21852
# Uploading file:processed/dandelion/train/img58.jpg
# 31555
# Uploading file:processed/roses/train/img41.jpg
# 9018
# Uploading file:processed/dandelion/train/img59.jpg
# 11298
# Uploading file:processed/roses/train/img42.jpg
# 16379
# Uploading file:processed/dandelion/train/img60.jpg
# 19099
# Uploading file:processed/daisy/train/img37.jpg
# 11982
# Uploading file:processed/sunflowers/train/img24.jpg
# 15752
# Uploading file:processed/daisy/train/img38.jpg
# 21079
# Uploading file:processed/sunflowers/train/img25.jpg
# 22971
# Uploading file:processed/roses/train/img43.jpg
# 22576
# Uploading file:processed/roses/train/img44.jpg
# 23047
# Uploading file:processed/roses/train/img45.jpg
# 26306
# Uploading file:processed/daisy/train/img39.jpg
# 16855
# Uploading file:processed/daisy/train/img40.jpg
# 9667
# Uploading file:processed/sunflowers/train/img26.jpg
# 21369
# Uploading file:processed/daisy/train/img41.jpg
# 10927
# Uploading file:processed/daisy/train/img42.jpg
# 14220
# Uploading file:processed/dandelion/train/img61.jpg
# 25325
# Uploading file:processed/daisy/train/img43.jpg
# 23996
# Uploading file:processed/dandelion/train/img62.jpg
# 13812
# Uploading file:processed/roses/train/img46.jpg
# 30395
# Uploading file:processed/daisy/train/img44.jpg
# 30996
# Uploading file:processed/sunflowers/train/img27.jpg
# 24519
# Uploading file:processed/dandelion/train/img63.jpg
# 14516
# Uploading file:processed/roses/train/img47.jpg
# 20763
# Uploading file:processed/dandelion/train/img64.jpg
# 10221
# Uploading file:processed/dandelion/train/img65.jpg
# 23052
# Uploading file:processed/roses/train/img48.jpg
# 12005
# Uploading file:processed/roses/train/img49.jpg
# 14610
# Uploading file:processed/roses/train/img50.jpg
# 8145
# Uploading file:processed/roses/train/img51.jpg
# 14293
# Uploading file:processed/roses/train/img52.jpg
# 21055
# Uploading file:processed/sunflowers/train/img28.jpg
# 30981
# Uploading file:processed/daisy/train/img45.jpg
# 15593
# Uploading file:processed/roses/train/img53.jpg
# 11905
# Uploading file:processed/sunflowers/train/img29.jpg
# 9131
# Uploading file:processed/daisy/train/img46.jpg
# 10868
# Uploading file:processed/dandelion/train/img66.jpg
# 11368
# Uploading file:processed/sunflowers/train/img30.jpg
# 37133
# Uploading file:processed/dandelion/train/img67.jpg
# 20895
# Uploading file:processed/dandelion/train/img68.jpg
# 21223
# Uploading file:processed/roses/train/img54.jpg
# 15333
# Uploading file:processed/daisy/train/img47.jpg
# 7238
# Uploading file:processed/dandelion/train/img69.jpg
# 16196
# Uploading file:processed/sunflowers/train/img31.jpg
# 25730
# Uploading file:processed/sunflowers/train/img32.jpg
# 25069
# Uploading file:processed/dandelion/train/img70.jpg
# 11363
# Uploading file:processed/daisy/train/img48.jpg
# 8359
# Uploading file:processed/roses/train/img55.jpg
# 16650
# Uploading file:processed/sunflowers/train/img33.jpg
# 18033
# Uploading file:processed/daisy/train/img49.jpg
# 11495
# Uploading file:processed/daisy/train/img50.jpg
# 16201
# Uploading file:processed/daisy/train/img51.jpg
# 10466
# Uploading file:processed/roses/train/img56.jpg
# 15107
# Uploading file:processed/dandelion/train/img71.jpg
# 18166
# Uploading file:processed/dandelion/train/img72.jpg
# 22176
# Uploading file:processed/dandelion/train/img73.jpg
# 19169
# Uploading file:processed/roses/train/img57.jpg
# 16102
# Uploading file:processed/daisy/train/img52.jpg
# 33756
# Uploading file:processed/dandelion/train/img74.jpg
# 21339
# Uploading file:processed/sunflowers/train/img34.jpg
# 21637
# Uploading file:processed/daisy/train/img53.jpg
# 28040
# Uploading file:processed/daisy/train/img54.jpg
# 17522
# Uploading file:processed/daisy/train/img55.jpg
# 27322
# Uploading file:processed/roses/train/img58.jpg
# 14730
# Uploading file:processed/roses/train/img59.jpg
# 14465
# Uploading file:processed/dandelion/train/img75.jpg
# 13671
# Uploading file:processed/roses/train/img60.jpg
# 23344
# Uploading file:processed/dandelion/train/img76.jpg
# 5920
# Uploading file:processed/sunflowers/train/img35.jpg
# 31260
# Uploading file:processed/dandelion/train/img77.jpg
# 17336
# Uploading file:processed/roses/train/img61.jpg
# 17120
# Uploading file:processed/roses/train/img62.jpg
# 18175
# Uploading file:processed/sunflowers/train/img36.jpg
# 24804
# Uploading file:processed/dandelion/train/img78.jpg
# 10512
# Uploading file:processed/dandelion/train/img79.jpg
# 10403
# Uploading file:processed/sunflowers/train/img37.jpg
# 21792
# Uploading file:processed/dandelion/train/img80.jpg
# 23856
# Uploading file:processed/roses/train/img63.jpg
# 27373
# Uploading file:processed/dandelion/train/img81.jpg
# 9691
# Uploading file:processed/dandelion/train/img82.jpg
# 21846
# Uploading file:processed/roses/train/img64.jpg
# 11344
# Uploading file:processed/roses/train/img65.jpg
# 34238
# Uploading file:processed/dandelion/train/img83.jpg
# 23710
# Uploading file:processed/dandelion/train/img84.jpg
# 22474
# Uploading file:processed/daisy/train/img56.jpg
# 17199
# Uploading file:processed/dandelion/train/img85.jpg
# 21253
# Uploading file:processed/daisy/train/img57.jpg
# 6807
# Uploading file:processed/roses/train/img66.jpg
# 27025
# Uploading file:processed/dandelion/train/img86.jpg
# 14706
# Uploading file:processed/dandelion/train/img87.jpg
# 14693
# Uploading file:processed/sunflowers/train/img38.jpg
# 19662
# Uploading file:processed/sunflowers/train/img39.jpg
# 13549
# Uploading file:processed/sunflowers/train/img40.jpg
# 25697
# Uploading file:processed/dandelion/train/img88.jpg
# 16661
# Uploading file:processed/dandelion/train/img89.jpg
# 9288
# Uploading file:processed/sunflowers/train/img41.jpg
# 22353
# Uploading file:processed/daisy/train/img58.jpg
# 14131
# Uploading file:processed/daisy/train/img59.jpg
# 10774
# Uploading file:processed/sunflowers/train/img42.jpg
# 24200
# Uploading file:processed/dandelion/train/img90.jpg
# 8416
# Uploading file:processed/dandelion/train/img91.jpg
# 15196
# Uploading file:processed/roses/train/img67.jpg
# 21609
# Uploading file:processed/daisy/train/img60.jpg
# 11028
# Uploading file:processed/dandelion/train/img92.jpg
# 18082
# Uploading file:processed/daisy/train/img61.jpg
# 15893
# Uploading file:processed/roses/train/img68.jpg
# 40803
# Uploading file:processed/roses/train/img69.jpg
# 12966
# Uploading file:processed/sunflowers/train/img43.jpg
# 27842
# Uploading file:processed/daisy/train/img62.jpg
# 19527
# Uploading file:processed/roses/train/img70.jpg
# 23994
# Uploading file:processed/roses/train/img71.jpg
# 16650
# Uploading file:processed/roses/train/img72.jpg
# 19887
# Uploading file:processed/dandelion/train/img93.jpg
# 15402
# Uploading file:processed/roses/train/img73.jpg
# 14279
# Uploading file:processed/daisy/train/img63.jpg
# 19824
# Uploading file:processed/daisy/train/img64.jpg
# 35197
# Uploading file:processed/daisy/train/img65.jpg
# 12680
# Uploading file:processed/daisy/train/img66.jpg
# 12705
# Uploading file:processed/roses/train/img74.jpg
# 25224
# Uploading file:processed/sunflowers/train/img44.jpg
# 16424
# Uploading file:processed/daisy/train/img67.jpg
# 5788
# Uploading file:processed/dandelion/train/img94.jpg
# 16379
# Uploading file:processed/sunflowers/train/img45.jpg
# 17998
# Uploading file:processed/dandelion/train/img95.jpg
# 12994
# Uploading file:processed/dandelion/train/img96.jpg
# 20000
# Uploading file:processed/roses/train/img75.jpg
# 16936
# Uploading file:processed/roses/train/img76.jpg
# 13871
# Uploading file:processed/roses/train/img77.jpg
# 26375
# Uploading file:processed/sunflowers/train/img46.jpg
# 11166
# Uploading file:processed/roses/train/img78.jpg
# 16376
# Uploading file:processed/dandelion/train/img97.jpg
# 15512
# Uploading file:processed/roses/train/img79.jpg
# 13130
# Uploading file:processed/sunflowers/train/img47.jpg
# 19928
# Uploading file:processed/daisy/train/img68.jpg
# 24141
# Uploading file:processed/roses/train/img80.jpg
# 11092
# Uploading file:processed/daisy/train/img69.jpg
# 20049
# Uploading file:processed/dandelion/train/img98.jpg
# 18183
# Uploading file:processed/roses/train/img81.jpg
# 8819
# Uploading file:processed/daisy/train/img70.jpg
# 29111
# Uploading file:processed/sunflowers/train/img48.jpg
# 24935
# Uploading file:processed/sunflowers/train/img49.jpg
# 35411
# Uploading file:processed/roses/train/img82.jpg
# 24983
# Uploading file:processed/sunflowers/train/img50.jpg
# 19084
# Uploading file:processed/dandelion/train/img99.jpg
# 14736
# Uploading file:processed/daisy/train/img71.jpg
# 15187
# Uploading file:processed/daisy/train/img72.jpg
# 19799
# Uploading file:processed/sunflowers/train/img51.jpg
# 14619
# Uploading file:processed/daisy/train/img73.jpg
# 7253
# Uploading file:processed/daisy/train/img74.jpg
# 21592
# Uploading file:processed/roses/train/img83.jpg
# 13169
# Uploading file:processed/roses/train/img84.jpg
# 17985
# Uploading file:processed/dandelion/train/img100.jpg
# 16849
# Uploading file:processed/roses/train/img85.jpg
# 19568
# Uploading file:processed/dandelion/train/img101.jpg
# 10831
# Uploading file:processed/dandelion/train/img102.jpg
# 11549
# Uploading file:processed/dandelion/train/img103.jpg
# 22414
# Uploading file:processed/sunflowers/train/img52.jpg
# 22158
# Uploading file:processed/dandelion/train/img104.jpg
# 12175
# Uploading file:processed/roses/train/img86.jpg
# 9061
# Uploading file:processed/roses/train/img87.jpg
# 15889
# Uploading file:processed/daisy/train/img75.jpg
# 21206
# Uploading file:processed/sunflowers/train/img53.jpg
# 25081
# Uploading file:processed/roses/train/img88.jpg
# 14311
# Uploading file:processed/sunflowers/train/img54.jpg
# 16642
# Uploading file:processed/daisy/train/img76.jpg
# 14320
# Uploading file:processed/sunflowers/train/img55.jpg
# 26433
# Uploading file:processed/sunflowers/train/img56.jpg
# 20957
# Uploading file:processed/roses/train/img89.jpg
# 33694
# Uploading file:processed/dandelion/train/img105.jpg
# 13658
# Uploading file:processed/dandelion/train/img106.jpg
# 12734
# Uploading file:processed/daisy/train/img77.jpg
# 9754
# Uploading file:processed/dandelion/train/img107.jpg
# 15181
# Uploading file:processed/daisy/train/img78.jpg
# 9891
# Uploading file:processed/sunflowers/train/img57.jpg
# 33412
# Uploading file:processed/dandelion/train/img108.jpg
# 24006
# Uploading file:processed/sunflowers/train/img58.jpg
# 37382
# Uploading file:processed/dandelion/train/img109.jpg
# 10597
# Uploading file:processed/sunflowers/train/img59.jpg
# 27077
# Uploading file:processed/roses/train/img90.jpg
# 24498
# Uploading file:processed/roses/train/img91.jpg
# 30873
# Uploading file:processed/sunflowers/train/img60.jpg
# 13460
# Uploading file:processed/dandelion/train/img110.jpg
# 11622
# Uploading file:processed/roses/train/img92.jpg
# 32291
# Uploading file:processed/daisy/train/img79.jpg
# 8666
# Uploading file:processed/dandelion/train/img111.jpg
# 12741
# Uploading file:processed/daisy/train/img80.jpg
# 34133
# Uploading file:processed/dandelion/train/img112.jpg
# 14098
# Uploading file:processed/sunflowers/train/img61.jpg
# 20303
# Uploading file:processed/daisy/train/img81.jpg
# 14212
# Uploading file:processed/daisy/train/img82.jpg
# 14719
# Uploading file:processed/dandelion/train/img113.jpg
# 21054
# Uploading file:processed/daisy/train/img83.jpg
# 10869
# Uploading file:processed/daisy/train/img84.jpg
# 21319
# Uploading file:processed/daisy/train/img85.jpg
# 11447
# Uploading file:processed/daisy/train/img86.jpg
# 12289
# Uploading file:processed/dandelion/train/img114.jpg
# 18815
# Uploading file:processed/sunflowers/train/img62.jpg
# 23102
# Uploading file:processed/roses/train/img93.jpg
# 17751
# Uploading file:processed/sunflowers/train/img63.jpg
# 33303
# Uploading file:processed/dandelion/train/img115.jpg
# 20610
# Uploading file:processed/roses/train/img94.jpg
# 24040
# Uploading file:processed/roses/train/img95.jpg
# 16094
# Uploading file:processed/dandelion/train/img116.jpg
# 27169
# Uploading file:processed/sunflowers/train/img64.jpg
# 16828
# Uploading file:processed/roses/train/img96.jpg
# 13539
# Uploading file:processed/roses/train/img97.jpg
# 11257
# Uploading file:processed/daisy/train/img87.jpg
# 8942
# Uploading file:processed/dandelion/train/img117.jpg
# 8554
# Uploading file:processed/roses/train/img98.jpg
# 32776
# Uploading file:processed/sunflowers/train/img65.jpg
# 19272
# Uploading file:processed/daisy/train/img88.jpg
# 30152
# Uploading file:processed/dandelion/train/img118.jpg
# 17317
# Uploading file:processed/daisy/train/img89.jpg
# 11914
# Uploading file:processed/daisy/train/img90.jpg
# 13013
# Uploading file:processed/dandelion/train/img119.jpg
# 22152
# Uploading file:processed/roses/train/img99.jpg
# 8583
# Uploading file:processed/dandelion/train/img120.jpg
# 8392
# Uploading file:processed/roses/train/img100.jpg
# 19942
# Uploading file:processed/dandelion/train/img121.jpg
# 8879
# Uploading file:processed/daisy/train/img91.jpg
# 16459
# Uploading file:processed/sunflowers/train/img66.jpg
# 26138
# Uploading file:processed/dandelion/train/img122.jpg
# 17488
# Uploading file:processed/dandelion/train/img123.jpg
# 14369
# Uploading file:processed/sunflowers/train/img67.jpg
# 24336
# Uploading file:processed/roses/train/img101.jpg
# 19563
# Uploading file:processed/roses/train/img102.jpg
# 28472
# Uploading file:processed/dandelion/train/img124.jpg
# 23173
# Uploading file:processed/dandelion/train/img125.jpg
# 8259
# Uploading file:processed/daisy/train/img92.jpg
# 18820
# Uploading file:processed/roses/train/img103.jpg
# 11338
# Uploading file:processed/daisy/train/img93.jpg
# 20635
# Uploading file:processed/dandelion/train/img126.jpg
# 14213
# Uploading file:processed/roses/train/img104.jpg
# 14715
# Uploading file:processed/daisy/train/img94.jpg
# 28678
# Uploading file:processed/roses/train/img105.jpg
# 15429
# Uploading file:processed/dandelion/train/img127.jpg
# 10274
# Uploading file:processed/daisy/train/img95.jpg
# 18368
# Uploading file:processed/roses/train/img106.jpg
# 13623
# Uploading file:processed/dandelion/train/img128.jpg
# 24325
# Uploading file:processed/daisy/train/img96.jpg
# 16343
# Uploading file:processed/dandelion/train/img129.jpg
# 10765
# Uploading file:processed/dandelion/train/img130.jpg
# 14365
# Uploading file:processed/daisy/train/img97.jpg
# 9432
# Uploading file:processed/roses/train/img107.jpg
# 28666
# Uploading file:processed/dandelion/train/img131.jpg
# 15365
# Uploading file:processed/roses/train/img108.jpg
# 14781
# Uploading file:processed/dandelion/train/img132.jpg
# 23584
# Uploading file:processed/dandelion/train/img133.jpg
# 16608
# Uploading file:processed/dandelion/train/img134.jpg
# 9416
# Uploading file:processed/sunflowers/train/img68.jpg
# 25631
# Uploading file:processed/daisy/train/img98.jpg
# 9474
# Uploading file:processed/daisy/train/img99.jpg
# 15548
# Uploading file:processed/dandelion/train/img135.jpg
# 27453
# Uploading file:processed/sunflowers/train/img69.jpg
# 15282
# Uploading file:processed/dandelion/train/img136.jpg
# 25484
# Uploading file:processed/daisy/train/img100.jpg
# 11706
# Uploading file:processed/dandelion/train/img137.jpg
# 13271
# Uploading file:processed/daisy/train/img101.jpg
# 16023
# Uploading file:processed/daisy/train/img102.jpg
# 9931
# Uploading file:processed/sunflowers/train/img70.jpg
# 21085
# Uploading file:processed/sunflowers/train/img71.jpg
# 27011
# Uploading file:processed/dandelion/train/img138.jpg
# 17849
# Uploading file:processed/daisy/train/img103.jpg
# 13071
# Uploading file:processed/roses/train/img109.jpg
# 13761
# Uploading file:processed/roses/train/img110.jpg
# 11250
# Uploading file:processed/dandelion/train/img139.jpg
# 21044
# Uploading file:processed/daisy/train/img104.jpg
# 20120
# Uploading file:processed/dandelion/train/img140.jpg
# 29071
# Uploading file:processed/dandelion/train/img141.jpg
# 13278
# Uploading file:processed/sunflowers/train/img72.jpg
# 16969
# Uploading file:processed/dandelion/train/img142.jpg
# 14440
# Uploading file:processed/dandelion/train/img143.jpg
# 18214
# Uploading file:processed/roses/train/img111.jpg
# 14079
# Uploading file:processed/roses/train/img112.jpg
# 10661
# Uploading file:processed/roses/train/img113.jpg
# 15302
# Uploading file:processed/daisy/train/img105.jpg
# 26117
# Uploading file:processed/dandelion/train/img144.jpg
# 44067
# Uploading file:processed/dandelion/train/img145.jpg
# 8294
# Uploading file:processed/daisy/train/img106.jpg
# 18654
# Uploading file:processed/daisy/train/img107.jpg
# 10189
# Uploading file:processed/daisy/train/img108.jpg
# 12248
# Uploading file:processed/daisy/train/img109.jpg
# 8323
# Uploading file:processed/daisy/train/img110.jpg
# 19720
# Uploading file:processed/roses/train/img114.jpg
# 24281
# Uploading file:processed/roses/train/img115.jpg
# 13546
# Uploading file:processed/daisy/train/img111.jpg
# 26007
# Uploading file:processed/daisy/train/img112.jpg
# 11914
# Uploading file:processed/sunflowers/train/img73.jpg
# 15258
# Uploading file:processed/roses/train/img116.jpg
# 24121
# Uploading file:processed/dandelion/train/img146.jpg
# 23664
# Uploading file:processed/roses/train/img117.jpg
# 22973
# Uploading file:processed/dandelion/train/img147.jpg
# 21378
# Uploading file:processed/dandelion/train/img148.jpg
# 23611
# Uploading file:processed/dandelion/train/img149.jpg
# 18999
# Uploading file:processed/daisy/train/img113.jpg
# 15631
# Uploading file:processed/roses/train/img118.jpg
# 14297
# Uploading file:processed/roses/train/img119.jpg
# 15570
# Uploading file:processed/daisy/train/img114.jpg
# 16933
# Uploading file:processed/roses/train/img120.jpg
# 17919
# Uploading file:processed/dandelion/train/img150.jpg
# 10717
# Uploading file:processed/roses/train/img121.jpg
# 18914
# Uploading file:processed/daisy/train/img115.jpg
# 11254
# Uploading file:processed/dandelion/train/img151.jpg
# 45323
# Uploading file:processed/sunflowers/train/img74.jpg
# 20495
# Uploading file:processed/roses/train/img122.jpg
# 13668
# Uploading file:processed/daisy/train/img116.jpg
# 14077
# Uploading file:processed/daisy/train/img117.jpg
# 25565
# Uploading file:processed/roses/train/img123.jpg
# 12628
# Uploading file:processed/sunflowers/train/img75.jpg
# 40401
# Uploading file:processed/dandelion/train/img152.jpg
# 11957
# Uploading file:processed/daisy/train/img118.jpg
# 15121
# Uploading file:processed/daisy/train/img119.jpg
# 19402
# Uploading file:processed/sunflowers/train/img76.jpg
# 25770
# Uploading file:processed/dandelion/train/img153.jpg
# 18381
# Uploading file:processed/dandelion/train/img154.jpg
# 16033
# Uploading file:processed/dandelion/train/img155.jpg
# 11801
# Uploading file:processed/dandelion/train/img156.jpg
# 15498
# Uploading file:processed/daisy/train/img120.jpg
# 18987
# Uploading file:processed/dandelion/train/img157.jpg
# 12421
# Uploading file:processed/dandelion/train/img158.jpg
# 22015
# Uploading file:processed/roses/train/img124.jpg
# 14615
# Uploading file:processed/sunflowers/train/img77.jpg
# 33270
# Uploading file:processed/dandelion/train/img159.jpg
# 26108
# Uploading file:processed/sunflowers/train/img78.jpg
# 16803
# Uploading file:processed/dandelion/train/img160.jpg
# 28066
# Uploading file:processed/roses/train/img125.jpg
# 23866
# Uploading file:processed/daisy/train/img121.jpg
# 19734
# Uploading file:processed/daisy/train/img122.jpg
# 12116
# Uploading file:processed/roses/train/img126.jpg
# 24147
# Uploading file:processed/dandelion/train/img161.jpg
# 24522
# Uploading file:processed/roses/train/img127.jpg
# 14036
# Uploading file:processed/dandelion/train/img162.jpg
# 20606
# Uploading file:processed/dandelion/train/img163.jpg
# 18408
# Uploading file:processed/daisy/train/img123.jpg
# 17656
# Uploading file:processed/roses/train/img128.jpg
# 8473
# Uploading file:processed/sunflowers/train/img79.jpg
# 22937
# Uploading file:processed/roses/train/img129.jpg
# 10234
# Uploading file:processed/roses/train/img130.jpg
# 13828
# Uploading file:processed/dandelion/train/img164.jpg
# 13794
# Uploading file:processed/roses/train/img131.jpg
# 22433
# Uploading file:processed/sunflowers/train/img80.jpg
# 32937
# Uploading file:processed/dandelion/train/img165.jpg
# 10190
# Uploading file:processed/sunflowers/train/img81.jpg
# 27949
# Uploading file:processed/roses/train/img132.jpg
# 14294
# Uploading file:processed/roses/train/img133.jpg
# 17469
# Uploading file:processed/dandelion/train/img166.jpg
# 32976
# Uploading file:processed/sunflowers/train/img82.jpg
# 16138
# Uploading file:processed/roses/train/img134.jpg
# 35751
# Uploading file:processed/daisy/train/img124.jpg
# 14188
# Uploading file:processed/sunflowers/train/img83.jpg
# 20887
# Uploading file:processed/dandelion/train/img167.jpg
# 14834
# Uploading file:processed/roses/train/img135.jpg
# 10579
# Uploading file:processed/dandelion/train/img168.jpg
# 24691
# Uploading file:processed/roses/train/img136.jpg
# 13605
# Uploading file:processed/dandelion/train/img169.jpg
# 22404
# Uploading file:processed/dandelion/train/img170.jpg
# 31372
# Uploading file:processed/dandelion/train/img171.jpg
# 18029
# Uploading file:processed/roses/train/img137.jpg
# 23762
# Uploading file:processed/daisy/train/img125.jpg
# 26274
# Uploading file:processed/dandelion/train/img172.jpg
# 22239
# Uploading file:processed/sunflowers/train/img84.jpg
# 16432
# Uploading file:processed/dandelion/train/img173.jpg
# 21909
# Uploading file:processed/dandelion/train/img174.jpg
# 19602
# Uploading file:processed/sunflowers/train/img85.jpg
# 12924
# Uploading file:processed/roses/train/img138.jpg
# 12112
# Uploading file:processed/roses/train/img139.jpg
# 22017
# Uploading file:processed/dandelion/train/img175.jpg
# 16939
# Uploading file:processed/daisy/train/img126.jpg
# 12020
# Uploading file:processed/dandelion/train/img176.jpg
# 40008
# Uploading file:processed/roses/train/img140.jpg
# 17352
# Uploading file:processed/daisy/train/img127.jpg
# 32631
# Uploading file:processed/roses/train/img141.jpg
# 14629
# Uploading file:processed/dandelion/train/img177.jpg
# 16783
# Uploading file:processed/sunflowers/train/img86.jpg
# 28562
# Uploading file:processed/roses/train/img142.jpg
# 11823
# Uploading file:processed/dandelion/train/img178.jpg
# 21656
# Uploading file:processed/roses/train/img143.jpg
# 7725
# Uploading file:processed/dandelion/train/img179.jpg
# 18322
# Uploading file:processed/sunflowers/train/img87.jpg
# 31051
# Uploading file:processed/dandelion/train/img180.jpg
# 16810
# Uploading file:processed/dandelion/train/img181.jpg
# 24322
# Uploading file:processed/dandelion/train/img182.jpg
# 17661
# Uploading file:processed/sunflowers/train/img88.jpg
# 17353
# Uploading file:processed/sunflowers/train/img89.jpg
# 15425
# Uploading file:processed/dandelion/train/img183.jpg
# 39037
# Uploading file:processed/daisy/train/img128.jpg
# 7656
# Uploading file:processed/roses/train/img144.jpg
# 13094
# Uploading file:processed/dandelion/train/img184.jpg
# 23969
# Uploading file:processed/daisy/train/img129.jpg
# 30085
# Uploading file:processed/sunflowers/train/img90.jpg
# 24985
# Uploading file:processed/daisy/train/img130.jpg
# 19628
# Uploading file:processed/sunflowers/train/img91.jpg
# 25863
# Uploading file:processed/dandelion/train/img185.jpg
# 13569
# Uploading file:processed/dandelion/train/img186.jpg
# 8156
# Uploading file:processed/roses/train/img145.jpg
# 7417
# Uploading file:processed/roses/train/img146.jpg
# 11132
# Uploading file:processed/dandelion/train/img187.jpg
# 20719
# Uploading file:processed/roses/train/img147.jpg
# 26056
# Uploading file:processed/roses/train/img148.jpg
# 16480
# Uploading file:processed/roses/train/img149.jpg
# 14417
# Uploading file:processed/dandelion/train/img188.jpg
# 13362
# Uploading file:processed/daisy/train/img131.jpg
# 21325
# Uploading file:processed/dandelion/train/img189.jpg
# 17296
# Uploading file:processed/daisy/train/img132.jpg
# 21929
# Uploading file:processed/dandelion/train/img190.jpg
# 8514
# Uploading file:processed/sunflowers/train/img92.jpg
# 36312
# Uploading file:processed/dandelion/train/img191.jpg
# 21166
# Uploading file:processed/roses/train/img150.jpg
# 28914
# Uploading file:processed/daisy/train/img133.jpg
# 17955
# Uploading file:processed/dandelion/train/img192.jpg
# 21013
# Uploading file:processed/dandelion/train/img193.jpg
# 11517
# Uploading file:processed/daisy/train/img134.jpg
# 15819
# Uploading file:processed/sunflowers/train/img93.jpg
# 32799
# Uploading file:processed/dandelion/train/img194.jpg
# 23918
# Uploading file:processed/dandelion/train/img195.jpg
# 12931
# Uploading file:processed/daisy/train/img135.jpg
# 16192
# Uploading file:processed/roses/train/img151.jpg
# 27727
# Uploading file:processed/roses/train/img152.jpg
# 22238
# Uploading file:processed/daisy/train/img136.jpg
# 17789
# Uploading file:processed/dandelion/train/img196.jpg
# 12725
# Uploading file:processed/roses/train/img153.jpg
# 16423
# Uploading file:processed/roses/train/img154.jpg
# 13500
# Uploading file:processed/roses/train/img155.jpg
# 17342
# Uploading file:processed/sunflowers/train/img94.jpg
# 19620
# Uploading file:processed/daisy/train/img137.jpg
# 8502
# Uploading file:processed/daisy/train/img138.jpg
# 18067
# Uploading file:processed/dandelion/train/img197.jpg
# 6105
# Uploading file:processed/daisy/train/img139.jpg
# 12430
# Uploading file:processed/sunflowers/train/img95.jpg
# 16693
# Uploading file:processed/sunflowers/train/img96.jpg
# 12295
# Uploading file:processed/sunflowers/train/img97.jpg
# 19560
# Uploading file:processed/daisy/train/img140.jpg
# 19560
# Uploading file:processed/sunflowers/train/img98.jpg
# 11423
# Uploading file:processed/daisy/train/img141.jpg
# 9886
# Uploading file:processed/daisy/train/img142.jpg
# 16591
# Uploading file:processed/dandelion/train/img198.jpg
# 15493
# Uploading file:processed/dandelion/train/img199.jpg
# 21717
# Uploading file:processed/dandelion/train/img200.jpg
# 16222
# Uploading file:processed/daisy/train/img143.jpg
# 10953
# Uploading file:processed/sunflowers/train/img99.jpg
# 31576
# Uploading file:processed/sunflowers/train/img100.jpg
# 32242
# Uploading file:processed/daisy/train/img144.jpg
# 11894
# Uploading file:processed/sunflowers/train/img101.jpg
# 24403
# Uploading file:processed/daisy/train/img145.jpg
# 11273
# Uploading file:processed/daisy/train/img146.jpg
# 17660
# Uploading file:processed/dandelion/train/img201.jpg
# 11543
# Uploading file:processed/roses/train/img156.jpg
# 11248
# Uploading file:processed/dandelion/train/img202.jpg
# 21016
# Uploading file:processed/dandelion/train/img203.jpg
# 13953
# Uploading file:processed/dandelion/train/img204.jpg
# 21585
# Uploading file:processed/sunflowers/train/img102.jpg
# 17006
# Uploading file:processed/roses/train/img157.jpg
# 12120
# Uploading file:processed/roses/train/img158.jpg
# 20696
# Uploading file:processed/daisy/train/img147.jpg
# 12863
# Uploading file:processed/sunflowers/train/img103.jpg
# 36189
# Uploading file:processed/sunflowers/train/img104.jpg
# 17494
# Uploading file:processed/daisy/train/img148.jpg
# 13365
# Uploading file:processed/dandelion/train/img205.jpg
# 16721
# Uploading file:processed/dandelion/train/img206.jpg
# 23124
# Uploading file:processed/sunflowers/train/img105.jpg
# 8740
# Uploading file:processed/dandelion/train/img207.jpg
# 10451
# Uploading file:processed/dandelion/train/img208.jpg
# 20778
# Uploading file:processed/sunflowers/train/img106.jpg
# 21822
# Uploading file:processed/roses/train/img159.jpg
# 12823
# Uploading file:processed/dandelion/train/img209.jpg
# 19661
# Uploading file:processed/dandelion/train/img210.jpg
# 12595
# Uploading file:processed/dandelion/train/img211.jpg
# 10282
# Uploading file:processed/dandelion/train/img212.jpg
# 17629
# Uploading file:processed/daisy/train/img149.jpg
# 12741
# Uploading file:processed/roses/train/img160.jpg
# 18642
# Uploading file:processed/daisy/train/img150.jpg
# 47761
# Uploading file:processed/dandelion/train/img213.jpg
# 19462
# Uploading file:processed/dandelion/train/img214.jpg
# 14019
# Uploading file:processed/daisy/train/img151.jpg
# 12312
# Uploading file:processed/daisy/train/img152.jpg
# 15375
# Uploading file:processed/daisy/train/img153.jpg
# 13022
# Uploading file:processed/dandelion/train/img215.jpg
# 12962
# Uploading file:processed/roses/train/img161.jpg
# 24202
# Uploading file:processed/roses/train/img162.jpg
# 27276
# Uploading file:processed/dandelion/train/img216.jpg
# 15932
# Uploading file:processed/roses/train/img163.jpg
# 20485
# Uploading file:processed/dandelion/train/img217.jpg
# 24623
# Uploading file:processed/sunflowers/train/img107.jpg
# 33427
# Uploading file:processed/roses/train/img164.jpg
# 27405
# Uploading file:processed/daisy/train/img154.jpg
# 14679
# Uploading file:processed/dandelion/train/img218.jpg
# 13076
# Uploading file:processed/daisy/train/img155.jpg
# 35168
# Uploading file:processed/dandelion/train/img219.jpg
# 13519
# Uploading file:processed/roses/train/img165.jpg
# 19111
# Uploading file:processed/roses/train/img166.jpg
# 14732
# Uploading file:processed/dandelion/train/img220.jpg
# 15557
# Uploading file:processed/daisy/train/img156.jpg
# 18991
# Uploading file:processed/dandelion/train/img221.jpg
# 14826
# Uploading file:processed/dandelion/train/img222.jpg
# 18063
# Uploading file:processed/dandelion/train/img223.jpg
# 9891
# Uploading file:processed/roses/train/img167.jpg
# 8150
# Uploading file:processed/daisy/train/img157.jpg
# 20181
# Uploading file:processed/dandelion/train/img224.jpg
# 12336
# Uploading file:processed/daisy/train/img158.jpg
# 13257
# Uploading file:processed/roses/train/img168.jpg
# 15533
# Uploading file:processed/roses/train/img169.jpg
# 13137
# Uploading file:processed/dandelion/train/img225.jpg
# 13667
# Uploading file:processed/dandelion/train/img226.jpg
# 21619
# Uploading file:processed/dandelion/train/img227.jpg
# 21916
# Uploading file:processed/sunflowers/train/img108.jpg
# 40325
# Uploading file:processed/roses/train/img170.jpg
# 17778
# Uploading file:processed/roses/train/img171.jpg
# 33689
# Uploading file:processed/roses/train/img172.jpg
# 41528
# Uploading file:processed/dandelion/train/img228.jpg
# 10493
# Uploading file:processed/sunflowers/train/img109.jpg
# 22532
# Uploading file:processed/sunflowers/train/img110.jpg
# 18601
# Uploading file:processed/sunflowers/train/img111.jpg
# 25854
# Uploading file:processed/daisy/train/img159.jpg
# 13891
# Uploading file:processed/sunflowers/train/img112.jpg
# 32710
# Uploading file:processed/roses/train/img173.jpg
# 15317
# Uploading file:processed/dandelion/train/img229.jpg
# 17310
# Uploading file:processed/roses/train/img174.jpg
# 14459
# Uploading file:processed/sunflowers/train/img113.jpg
# 32010
# Uploading file:processed/dandelion/train/img230.jpg
# 12376
# Uploading file:processed/sunflowers/train/img114.jpg
# 20391
# Uploading file:processed/roses/train/img175.jpg
# 18253
# Uploading file:processed/daisy/train/img160.jpg
# 19633
# Uploading file:processed/dandelion/train/img231.jpg
# 12146
# Uploading file:processed/roses/train/img176.jpg
# 16648
# Uploading file:processed/dandelion/train/img232.jpg
# 27286
# Uploading file:processed/dandelion/train/img233.jpg
# 9082
# Uploading file:processed/daisy/train/img161.jpg
# 29628
# Uploading file:processed/roses/train/img177.jpg
# 27106
# Uploading file:processed/roses/train/img178.jpg
# 30559
# Uploading file:processed/daisy/train/img162.jpg
# 7773
# Uploading file:processed/dandelion/train/img234.jpg
# 18214
# Uploading file:processed/dandelion/train/img235.jpg
# 18524
# Uploading file:processed/dandelion/train/img236.jpg
# 13463
# Uploading file:processed/roses/train/img179.jpg
# 18413
# Uploading file:processed/daisy/train/img163.jpg
# 16889
# Uploading file:processed/roses/train/img180.jpg
# 29658
# Uploading file:processed/roses/train/img181.jpg
# 38366
# Uploading file:processed/dandelion/train/img237.jpg
# 20018
# Uploading file:processed/sunflowers/train/img115.jpg
# 30531
# Uploading file:processed/dandelion/train/img238.jpg
# 12212
# Uploading file:processed/roses/train/img182.jpg
# 16021
# Uploading file:processed/roses/train/img183.jpg
# 9459
# Uploading file:processed/roses/train/img184.jpg
# 15038
# Uploading file:processed/sunflowers/train/img116.jpg
# 22363
# Uploading file:processed/daisy/train/img164.jpg
# 13867
# Uploading file:processed/dandelion/train/img239.jpg
# 11696
# Uploading file:processed/dandelion/train/img240.jpg
# 21932
# Uploading file:processed/roses/train/img185.jpg
# 24738
# Uploading file:processed/daisy/train/img165.jpg
# 15789
# Uploading file:processed/dandelion/train/img241.jpg
# 17418
# Uploading file:processed/roses/train/img186.jpg
# 11196
# Uploading file:processed/sunflowers/train/img117.jpg
# 18361
# Uploading file:processed/dandelion/train/img242.jpg
# 24375
# Uploading file:processed/roses/train/img187.jpg
# 9464
# Uploading file:processed/daisy/train/img166.jpg
# 16964
# Uploading file:processed/dandelion/train/img243.jpg
# 15786
# Uploading file:processed/daisy/train/img167.jpg
# 19474
# Uploading file:processed/daisy/train/img168.jpg
# 17748
# Uploading file:processed/dandelion/train/img244.jpg
# 20419
# Uploading file:processed/roses/train/img188.jpg
# 15463
# Uploading file:processed/daisy/train/img169.jpg
# 11165
# Uploading file:processed/daisy/train/img170.jpg
# 16575
# Uploading file:processed/dandelion/train/img245.jpg
# 13707
# Uploading file:processed/daisy/train/img171.jpg
# 12711
# Uploading file:processed/dandelion/train/img246.jpg
# 32871
# Uploading file:processed/roses/train/img189.jpg
# 13916
# Uploading file:processed/dandelion/train/img247.jpg
# 25880
# Uploading file:processed/roses/train/img190.jpg
# 19978
# Uploading file:processed/roses/train/img191.jpg
# 24974
# Uploading file:processed/daisy/train/img172.jpg
# 12311
# Uploading file:processed/daisy/train/img173.jpg
# 9499
# Uploading file:processed/daisy/train/img174.jpg
# 36224
# Uploading file:processed/daisy/train/img175.jpg
# 15575
# Uploading file:processed/daisy/train/img176.jpg
# 10760
# Uploading file:processed/dandelion/train/img248.jpg
# 10394
# Uploading file:processed/roses/train/img192.jpg
# 13282
# Uploading file:processed/roses/train/img193.jpg
# 31555
# Uploading file:processed/sunflowers/train/img118.jpg
# 23544
# Uploading file:processed/dandelion/train/img249.jpg
# 15460
# Uploading file:processed/daisy/train/img177.jpg
# 11184
# Uploading file:processed/daisy/train/img178.jpg
# 35742
# Uploading file:processed/sunflowers/train/img119.jpg
# 12883
# Uploading file:processed/sunflowers/train/img120.jpg
# 20627
# Uploading file:processed/sunflowers/train/img121.jpg
# 19230
# Uploading file:processed/sunflowers/train/img122.jpg
# 18159
# Uploading file:processed/dandelion/train/img250.jpg
# 14656
# Uploading file:processed/daisy/train/img179.jpg
# 8884
# Uploading file:processed/sunflowers/train/img123.jpg
# 28577
# Uploading file:processed/dandelion/train/img251.jpg
# 13582
# Uploading file:processed/daisy/train/img180.jpg
# 11799
# Uploading file:processed/roses/train/img194.jpg
# 14783
# Uploading file:processed/sunflowers/train/img124.jpg
# 15772
# Uploading file:processed/daisy/train/img181.jpg
# 19558
# Uploading file:processed/roses/train/img195.jpg
# 26301
# Uploading file:processed/roses/train/img196.jpg
# 18757
# Uploading file:processed/dandelion/train/img252.jpg
# 15026
# Uploading file:processed/sunflowers/train/img125.jpg
# 21752
# Uploading file:processed/dandelion/train/img253.jpg
# 12300
# Uploading file:processed/roses/train/img197.jpg
# 19886
# Uploading file:processed/dandelion/train/img254.jpg
# 9052
# Uploading file:processed/roses/train/img198.jpg
# 16057
# Uploading file:processed/sunflowers/train/img126.jpg
# 35232
# Uploading file:processed/daisy/train/img182.jpg
# 29963
# Uploading file:processed/roses/train/img199.jpg
# 19093
# Uploading file:processed/dandelion/train/img255.jpg
# 29458
# Uploading file:processed/roses/train/img200.jpg
# 17688
# Uploading file:processed/roses/train/img201.jpg
# 10615
# Uploading file:processed/dandelion/train/img256.jpg
# 13536
# Uploading file:processed/roses/train/img202.jpg
# 21473
# Uploading file:processed/roses/train/img203.jpg
# 11168
# Uploading file:processed/dandelion/train/img257.jpg
# 30371
# Uploading file:processed/daisy/train/img183.jpg
# 16605
# Uploading file:processed/dandelion/train/img258.jpg
# 13710
# Uploading file:processed/roses/train/img204.jpg
# 17839
# Uploading file:processed/roses/train/img205.jpg
# 14095
# Uploading file:processed/sunflowers/train/img127.jpg
# 37728
# Uploading file:processed/dandelion/train/img259.jpg
# 16349
# Uploading file:processed/sunflowers/train/img128.jpg
# 26380
# Uploading file:processed/daisy/train/img184.jpg
# 18265
# Uploading file:processed/daisy/train/img185.jpg
# 13900
# Uploading file:processed/dandelion/train/img260.jpg
# 22083
# Uploading file:processed/dandelion/train/img261.jpg
# 15314
# Uploading file:processed/daisy/train/img186.jpg
# 14391
# Uploading file:processed/sunflowers/train/img129.jpg
# 16793
# Uploading file:processed/roses/train/img206.jpg
# 14266
# Uploading file:processed/dandelion/train/img262.jpg
# 21383
# Uploading file:processed/roses/train/img207.jpg
# 22605
# Uploading file:processed/daisy/train/img187.jpg
# 12573
# Uploading file:processed/sunflowers/train/img130.jpg
# 14164
# Uploading file:processed/dandelion/train/img263.jpg
# 9841
# Uploading file:processed/sunflowers/train/img131.jpg
# 26486
# Uploading file:processed/dandelion/train/img264.jpg
# 9056
# Uploading file:processed/sunflowers/train/img132.jpg
# 16076
# Uploading file:processed/dandelion/train/img265.jpg
# 12226
# Uploading file:processed/roses/train/img208.jpg
# 14958
# Uploading file:processed/sunflowers/train/img133.jpg
# 24401
# Uploading file:processed/roses/train/img209.jpg
# 20451
# Uploading file:processed/dandelion/train/img266.jpg
# 16598
# Uploading file:processed/dandelion/train/img267.jpg
# 12966
# Uploading file:processed/daisy/train/img188.jpg
# 7927
# Uploading file:processed/roses/train/img210.jpg
# 17447
# Uploading file:processed/sunflowers/train/img134.jpg
# 37164
# Uploading file:processed/roses/train/img211.jpg
# 15068
# Uploading file:processed/roses/train/img212.jpg
# 16229
# Uploading file:processed/dandelion/train/img268.jpg
# 29758
# Uploading file:processed/daisy/train/img189.jpg
# 14508
# Uploading file:processed/dandelion/train/img269.jpg
# 15162
# Uploading file:processed/daisy/train/img190.jpg
# 27949
# Uploading file:processed/dandelion/train/img270.jpg
# 15660
# Uploading file:processed/sunflowers/train/img135.jpg
# 27865
# Uploading file:processed/roses/train/img213.jpg
# 11089
# Uploading file:processed/dandelion/train/img271.jpg
# 14371
# Uploading file:processed/roses/train/img214.jpg
# 28014
# Uploading file:processed/roses/train/img215.jpg
# 19271
# Uploading file:processed/dandelion/train/img272.jpg
# 13239
# Uploading file:processed/dandelion/train/img273.jpg
# 19589
# Uploading file:processed/daisy/train/img191.jpg
# 10920
# Uploading file:processed/dandelion/train/img274.jpg
# 13436
# Uploading file:processed/sunflowers/train/img136.jpg
# 34039
# Uploading file:processed/dandelion/train/img275.jpg
# 22298
# Uploading file:processed/roses/train/img216.jpg
# 17835
# Uploading file:processed/daisy/train/img192.jpg
# 19326
# Uploading file:processed/roses/train/img217.jpg
# 15036
# Uploading file:processed/dandelion/train/img276.jpg
# 13114
# Uploading file:processed/roses/train/img218.jpg
# 11656
# Uploading file:processed/sunflowers/train/img137.jpg
# 31417
# Uploading file:processed/dandelion/train/img277.jpg
# 14584
# Uploading file:processed/roses/train/img219.jpg
# 12579
# Uploading file:processed/roses/train/img220.jpg
# 19646
# Uploading file:processed/daisy/train/img193.jpg
# 33005
# Uploading file:processed/dandelion/train/img278.jpg
# 15107
# Uploading file:processed/sunflowers/train/img138.jpg
# 12874
# Uploading file:processed/daisy/train/img194.jpg
# 14331
# Uploading file:processed/sunflowers/train/img139.jpg
# 25379
# Uploading file:processed/roses/train/img221.jpg
# 19905
# Uploading file:processed/sunflowers/train/img140.jpg
# 20307
# Uploading file:processed/dandelion/train/img279.jpg
# 21704
# Uploading file:processed/daisy/train/img195.jpg
# 20136
# Uploading file:processed/dandelion/train/img280.jpg
# 37548
# Uploading file:processed/daisy/train/img196.jpg
# 20144
# Uploading file:processed/dandelion/train/img281.jpg
# 11708
# Uploading file:processed/dandelion/train/img282.jpg
# 8157
# Uploading file:processed/roses/train/img222.jpg
# 17046
# Uploading file:processed/daisy/train/img197.jpg
# 22543
# Uploading file:processed/dandelion/train/img283.jpg
# 11935
# Uploading file:processed/roses/train/img223.jpg
# 12948
# Uploading file:processed/dandelion/train/img284.jpg
# 23827
# Uploading file:processed/dandelion/train/img285.jpg
# 14343
# Uploading file:processed/roses/train/img224.jpg
# 25856
# Uploading file:processed/dandelion/train/img286.jpg
# 19294
# Uploading file:processed/roses/train/img225.jpg
# 36296
# Uploading file:processed/roses/train/img226.jpg
# 21540
# Uploading file:processed/roses/train/img227.jpg
# 8394
# Uploading file:processed/daisy/train/img198.jpg
# 15466
# Uploading file:processed/roses/train/img228.jpg
# 27634
# Uploading file:processed/dandelion/train/img287.jpg
# 25702
# Uploading file:processed/daisy/train/img199.jpg
# 14747
# Uploading file:processed/roses/train/img229.jpg
# 25320
# Uploading file:processed/dandelion/train/img288.jpg
# 21775
# Uploading file:processed/dandelion/train/img289.jpg
# 17018
# Uploading file:processed/dandelion/train/img290.jpg
# 7125
# Uploading file:processed/sunflowers/train/img141.jpg
# 26493
# Uploading file:processed/roses/train/img230.jpg
# 9835
# Uploading file:processed/dandelion/train/img291.jpg
# 12509
# Uploading file:processed/daisy/train/img200.jpg
# 21742
# ...
# 25377
# Uploading file:processed/daisy/train/img377.jpg
# 17199
# Uploading file:processed/roses/train/img391.jpg
# 25850
# Uploading file:processed/dandelion/train/img521.jpg
# 10969
# Uploading file:processed/roses/train/img392.jpg
# 23347
# Uploading file:processed/daisy/train/img378.jpg
# 15876
# Uploading file:processed/daisy/train/img379.jpg
# 14342
# Uploading file:processed/daisy/train/img380.jpg
# 11730
# Uploading file:processed/roses/train/img393.jpg
# 16293
# Uploading file:processed/sunflowers/train/img248.jpg
# 22896
# Uploading file:processed/dandelion/train/img522.jpg
# 12980
# Uploading file:processed/roses/train/img394.jpg
# 11503
# Uploading file:processed/dandelion/train/img523.jpg
# 16368
# Uploading file:processed/roses/train/img395.jpg
# 23539
# Uploading file:processed/daisy/train/img381.jpg
# 27929
# Uploading file:processed/dandelion/train/img524.jpg
# 14554
# Uploading file:processed/roses/train/img396.jpg
# 22494
# Uploading file:processed/sunflowers/train/img249.jpg
# 22616
# Uploading file:processed/daisy/train/img382.jpg
# 18229
# Uploading file:processed/roses/train/img397.jpg
# 12704
# Uploading file:processed/daisy/train/img383.jpg
# 18632
# Uploading file:processed/roses/train/img398.jpg
# 12557
# Uploading file:processed/roses/train/img399.jpg
# 28204
# Uploading file:processed/sunflowers/train/img250.jpg
# 28787
# Uploading file:processed/roses/train/img400.jpg
# 15430
# Uploading file:processed/daisy/train/img384.jpg
# 30816
# Uploading file:processed/dandelion/train/img525.jpg
# 11163
# Uploading file:processed/dandelion/train/img526.jpg
# 7113
# Uploading file:processed/roses/train/img401.jpg
# 21738
# Uploading file:processed/roses/train/img402.jpg
# 11303
# Uploading file:processed/sunflowers/train/img251.jpg
# 27088
# Uploading file:processed/roses/train/img403.jpg
# 17299
# Uploading file:processed/roses/train/img404.jpg
# 25708
# Uploading file:processed/sunflowers/train/img252.jpg
# 36259
# Uploading file:processed/dandelion/train/img527.jpg
# 27370
# Uploading file:processed/daisy/train/img385.jpg
# 9730
# Uploading file:processed/sunflowers/train/img253.jpg
# 31783
# Uploading file:processed/dandelion/train/img528.jpg
# 37165
# Uploading file:processed/sunflowers/train/img254.jpg
# 24187
# Uploading file:processed/dandelion/train/img529.jpg
# 13761
# Uploading file:processed/daisy/train/img386.jpg
# 12447
# Uploading file:processed/sunflowers/train/img255.jpg
# 25327
# Uploading file:processed/roses/train/img405.jpg
# 19206
# Uploading file:processed/dandelion/train/img530.jpg
# 20161
# Uploading file:processed/dandelion/train/img531.jpg
# 10903
# Uploading file:processed/roses/train/img406.jpg
# 23823
# Uploading file:processed/daisy/train/img387.jpg
# 21882
# Uploading file:processed/roses/train/img407.jpg
# 14522
# Uploading file:processed/daisy/train/img388.jpg
# 26707
# Uploading file:processed/daisy/train/img389.jpg
# 19139
# Uploading file:processed/daisy/train/img390.jpg
# 15926
# Uploading file:processed/dandelion/train/img532.jpg
# 15612
# Uploading file:processed/daisy/train/img391.jpg
# 35915
# Uploading file:processed/dandelion/train/img533.jpg
# 26259
# Uploading file:processed/dandelion/train/img534.jpg
# 17661
# Uploading file:processed/roses/train/img408.jpg
# 14435
# Uploading file:processed/dandelion/train/img535.jpg
# 7335
# Uploading file:processed/daisy/train/img392.jpg
# 27347
# Uploading file:processed/dandelion/train/img536.jpg
# 13943
# Uploading file:processed/sunflowers/train/img256.jpg
# 20464
# Uploading file:processed/roses/train/img409.jpg
# 18534
# Uploading file:processed/daisy/train/img393.jpg
# 15038
# Uploading file:processed/roses/train/img410.jpg
# 27124
# Uploading file:processed/roses/train/img411.jpg
# 26593
# Uploading file:processed/dandelion/train/img537.jpg
# 12036
# Uploading file:processed/daisy/train/img394.jpg
# 29293
# Uploading file:processed/sunflowers/train/img257.jpg
# 29427
# Uploading file:processed/dandelion/train/img538.jpg
# 9864
# Uploading file:processed/roses/train/img412.jpg
# 16446
# Uploading file:processed/dandelion/train/img539.jpg
# 21885
# Uploading file:processed/roses/train/img413.jpg
# 16929
# Uploading file:processed/daisy/train/img395.jpg
# 14301
# Uploading file:processed/daisy/train/img396.jpg
# 24287
# Uploading file:processed/dandelion/train/img540.jpg
# 11300
# Uploading file:processed/dandelion/train/img541.jpg
# 34503
# Uploading file:processed/daisy/train/img397.jpg
# 14782
# Uploading file:processed/dandelion/train/img542.jpg
# 34501
# Uploading file:processed/sunflowers/train/img258.jpg
# 14081
# Uploading file:processed/sunflowers/train/img259.jpg
# 23132
# Uploading file:processed/sunflowers/train/img260.jpg
# 20473
# Uploading file:processed/dandelion/train/img543.jpg
# 15803
# Uploading file:processed/dandelion/train/img544.jpg
# 11506
# Uploading file:processed/dandelion/train/img545.jpg
# 11742
# Uploading file:processed/daisy/train/img398.jpg
# 20535
# Uploading file:processed/daisy/train/img399.jpg
# 15154
# Uploading file:processed/roses/train/img414.jpg
# 16801
# Uploading file:processed/daisy/train/img400.jpg
# 14212
# Uploading file:processed/dandelion/train/img546.jpg
# 12828
# Uploading file:processed/daisy/train/img401.jpg
# 17504
# Uploading file:processed/roses/train/img415.jpg
# 10979
# Uploading file:processed/roses/train/img416.jpg
# 12369
# Uploading file:processed/roses/train/img417.jpg
# 26030
# Uploading file:processed/dandelion/train/img547.jpg
# 15514
# Uploading file:processed/dandelion/train/img548.jpg
# 29230
# Uploading file:processed/roses/train/img418.jpg
# 17601
# Uploading file:processed/roses/train/img419.jpg
# 24385
# Uploading file:processed/sunflowers/train/img261.jpg
# 21285
# Uploading file:processed/dandelion/train/img549.jpg
# 13670
# Uploading file:processed/dandelion/train/img550.jpg
# 33800
# Uploading file:processed/dandelion/train/img551.jpg
# 5949
# Uploading file:processed/sunflowers/train/img262.jpg
# 31464
# Uploading file:processed/roses/train/img420.jpg
# 12235
# Uploading file:processed/dandelion/train/img552.jpg
# 17463
# Uploading file:processed/daisy/train/img402.jpg
# 10416
# Uploading file:processed/dandelion/train/img553.jpg
# 19578
# Uploading file:processed/sunflowers/train/img263.jpg
# 22072
# Uploading file:processed/sunflowers/train/img264.jpg
# 13893
# Uploading file:processed/roses/train/img421.jpg
# 28394
# Uploading file:processed/dandelion/train/img554.jpg
# 12545
# Uploading file:processed/dandelion/train/img555.jpg
# 20260
# Uploading file:processed/roses/train/img422.jpg
# 19324
# Uploading file:processed/sunflowers/train/img265.jpg
# 22300
# Uploading file:processed/roses/train/img423.jpg
# 23842
# Uploading file:processed/sunflowers/train/img266.jpg
# 32615
# Uploading file:processed/dandelion/train/img556.jpg
# 13046
# Uploading file:processed/sunflowers/train/img267.jpg
# 19000
# Uploading file:processed/daisy/train/img403.jpg
# 14037
# Uploading file:processed/dandelion/train/img557.jpg
# 26488
# Uploading file:processed/roses/train/img424.jpg
# 19739
# Uploading file:processed/sunflowers/train/img268.jpg
# 33055
# Uploading file:processed/dandelion/train/img558.jpg
# 15138
# Uploading file:processed/daisy/train/img404.jpg
# 13182
# Uploading file:processed/daisy/train/img405.jpg
# 13121
# Uploading file:processed/dandelion/train/img559.jpg
# 18403
# Uploading file:processed/roses/train/img425.jpg
# 19162
# Uploading file:processed/sunflowers/train/img269.jpg
# 17399
# Uploading file:processed/roses/train/img426.jpg
# 19218
# Uploading file:processed/roses/train/img427.jpg
# 15875
# Uploading file:processed/daisy/train/img406.jpg
# 15379
# Uploading file:processed/roses/train/img428.jpg
# 8497
# Uploading file:processed/dandelion/train/img560.jpg
# 18449
# Uploading file:processed/dandelion/train/img561.jpg
# 16345
# Uploading file:processed/dandelion/train/img562.jpg
# 27211
# Uploading file:processed/daisy/train/img407.jpg
# 18447
# Uploading file:processed/daisy/train/img408.jpg
# 19252
# Uploading file:processed/dandelion/train/img563.jpg
# 21531
# Uploading file:processed/daisy/train/img409.jpg
# 29126
# Uploading file:processed/dandelion/train/img564.jpg
# 22253
# Uploading file:processed/roses/train/img429.jpg
# 17647
# Uploading file:processed/dandelion/train/img565.jpg
# 15503
# Uploading file:processed/daisy/train/img410.jpg
# 22359
# Uploading file:processed/dandelion/train/img566.jpg
# 15594
# Uploading file:processed/roses/train/img430.jpg
# 22408
# Uploading file:processed/dandelion/train/img567.jpg
# 13593
# Uploading file:processed/dandelion/train/img568.jpg
# 21311
# Uploading file:processed/daisy/train/img411.jpg
# 18179
# Uploading file:processed/dandelion/train/img569.jpg
# 11397
# Uploading file:processed/sunflowers/train/img270.jpg
# 22519
# Uploading file:processed/roses/train/img431.jpg
# 14138
# Uploading file:processed/daisy/train/img412.jpg
# 13924
# Uploading file:processed/dandelion/train/img570.jpg
# 13805
# Uploading file:processed/daisy/train/img413.jpg
# 22223
# Uploading file:processed/roses/train/img432.jpg
# 18489
# Uploading file:processed/roses/train/img433.jpg
# 13530
# Uploading file:processed/sunflowers/train/img271.jpg
# 33074
# Uploading file:processed/dandelion/train/img571.jpg
# 25262
# Uploading file:processed/dandelion/train/img572.jpg
# 13151
# Uploading file:processed/roses/train/img434.jpg
# 27013
# Uploading file:processed/sunflowers/train/img272.jpg
# 25780
# Uploading file:processed/sunflowers/train/img273.jpg
# 21283
# Uploading file:processed/roses/train/img435.jpg
# 16661
# Uploading file:processed/sunflowers/train/img274.jpg
# 28618
# Uploading file:processed/dandelion/train/img573.jpg
# 9903
# Uploading file:processed/dandelion/train/img574.jpg
# 13487
# Uploading file:processed/roses/train/img436.jpg
# 21991
# Uploading file:processed/roses/train/img437.jpg
# 18768
# Uploading file:processed/daisy/train/img414.jpg
# 10711
# Uploading file:processed/daisy/train/img415.jpg
# 11067
# Uploading file:processed/roses/train/img438.jpg
# 13192
# Uploading file:processed/dandelion/train/img575.jpg
# 14245
# Uploading file:processed/dandelion/train/img576.jpg
# 7433
# Uploading file:processed/sunflowers/train/img275.jpg
# 27837
# Uploading file:processed/dandelion/train/img577.jpg
# 16627
# Uploading file:processed/dandelion/train/img578.jpg
# 17844
# Uploading file:processed/dandelion/train/img579.jpg
# 17752
# Uploading file:processed/sunflowers/train/img276.jpg
# 15022
# Uploading file:processed/dandelion/train/img580.jpg
# 11863
# Uploading file:processed/roses/train/img439.jpg
# 12329
# Uploading file:processed/dandelion/train/img581.jpg
# 16499
# Uploading file:processed/daisy/train/img416.jpg
# 19693
# Uploading file:processed/dandelion/train/img582.jpg
# 20379
# Uploading file:processed/roses/train/img440.jpg
# 18359
# Uploading file:processed/sunflowers/train/img277.jpg
# 28832
# Uploading file:processed/dandelion/train/img583.jpg
# 18953
# Uploading file:processed/roses/train/img441.jpg
# 16545
# Uploading file:processed/roses/train/img442.jpg
# 31867
# Uploading file:processed/dandelion/train/img584.jpg
# 7580
# Uploading file:processed/sunflowers/train/img278.jpg
# 22719
# Uploading file:processed/dandelion/train/img585.jpg
# 20584
# Uploading file:processed/dandelion/train/img586.jpg
# 17440
# Uploading file:processed/roses/train/img443.jpg
# 13383
# Uploading file:processed/roses/train/img444.jpg
# 11792
# Uploading file:processed/roses/train/img445.jpg
# 13287
# Uploading file:processed/dandelion/train/img587.jpg
# 19391
# Uploading file:processed/sunflowers/train/img279.jpg
# 15977
# Uploading file:processed/roses/train/img446.jpg
# 11574
# Uploading file:processed/dandelion/train/img588.jpg
# 9069
# Uploading file:processed/dandelion/train/img589.jpg
# 7848
# Uploading file:processed/dandelion/train/img590.jpg
# 6272
# Uploading file:processed/dandelion/train/img591.jpg
# 23996
# Uploading file:processed/daisy/train/img417.jpg
# 7698
# Uploading file:processed/dandelion/train/img592.jpg
# 25785
# Uploading file:processed/roses/train/img447.jpg
# 12406
# Uploading file:processed/daisy/train/img418.jpg
# 15471
# Uploading file:processed/dandelion/train/img593.jpg
# 19382
# Uploading file:processed/sunflowers/train/img280.jpg
# 29651
# Uploading file:processed/dandelion/train/img594.jpg
# 24006
# Uploading file:processed/dandelion/train/img595.jpg
# 24938
# Uploading file:processed/sunflowers/train/img281.jpg
# 21861
# Uploading file:processed/dandelion/train/img596.jpg
# 9723
# Uploading file:processed/daisy/train/img419.jpg
# 15946
# Uploading file:processed/dandelion/train/img597.jpg
# 19973
# Uploading file:processed/daisy/train/img420.jpg
# 16451
# Uploading file:processed/dandelion/train/img598.jpg
# 20598
# Uploading file:processed/dandelion/train/img599.jpg
# 22683
# Uploading file:processed/dandelion/train/img600.jpg
# 17658
# Uploading file:processed/sunflowers/train/img282.jpg
# 17984
# Uploading file:processed/dandelion/train/img601.jpg
# 10744
# Uploading file:processed/daisy/train/img421.jpg
# 20511
# Uploading file:processed/sunflowers/train/img283.jpg
# 32165
# Uploading file:processed/roses/train/img448.jpg
# 16527
# Uploading file:processed/roses/train/img449.jpg
# 17127
# Uploading file:processed/sunflowers/train/img284.jpg
# 17325
# Uploading file:processed/dandelion/train/img602.jpg
# 9239
# Uploading file:processed/dandelion/train/img603.jpg
# 19280
# Uploading file:processed/daisy/train/img422.jpg
# 18787
# Uploading file:processed/dandelion/train/img604.jpg
# 15749
# Uploading file:processed/dandelion/train/img605.jpg
# 25454
# Uploading file:processed/sunflowers/train/img285.jpg
# 15106
# Uploading file:processed/dandelion/train/img606.jpg
# 13218
# Uploading file:processed/roses/train/img450.jpg
# 21807
# Uploading file:processed/daisy/train/img423.jpg
# 13480
# Uploading file:processed/dandelion/train/img607.jpg
# 16716
# Uploading file:processed/sunflowers/train/img286.jpg
# 31470
# Uploading file:processed/roses/train/img451.jpg
# 12937
# Uploading file:processed/sunflowers/train/img287.jpg
# 15033
# Uploading file:processed/dandelion/train/img608.jpg
# 10330
# Uploading file:processed/daisy/train/img424.jpg
# 18930
# Uploading file:processed/daisy/train/img425.jpg
# 19247
# Uploading file:processed/sunflowers/train/img288.jpg
# 24380
# Uploading file:processed/dandelion/train/img609.jpg
# 17813
# Uploading file:processed/dandelion/train/img610.jpg
# 11974
# Uploading file:processed/roses/train/img452.jpg
# 16172
# Uploading file:processed/daisy/train/img426.jpg
# 15513
# Uploading file:processed/roses/train/img453.jpg
# 16976
# Uploading file:processed/roses/train/img454.jpg
# 13960
# Uploading file:processed/roses/train/img455.jpg
# 14295
# Uploading file:processed/daisy/train/img427.jpg
# 21462
# Uploading file:processed/sunflowers/train/img289.jpg
# 25940
# Uploading file:processed/daisy/train/img428.jpg
# 34316
# Uploading file:processed/daisy/train/img429.jpg
# 15558
# Uploading file:processed/sunflowers/train/img290.jpg
# 29248
# Uploading file:processed/dandelion/train/img611.jpg
# 12220
# Uploading file:processed/dandelion/train/img612.jpg
# 28971
# Uploading file:processed/sunflowers/train/img291.jpg
# 14401
# Uploading file:processed/roses/train/img456.jpg
# 5432
# Uploading file:processed/dandelion/train/img613.jpg
# 16177
# Uploading file:processed/sunflowers/train/img292.jpg
# 31438
# Uploading file:processed/roses/train/img457.jpg
# 18459
# Uploading file:processed/dandelion/train/img614.jpg
# 16402
# Uploading file:processed/roses/train/img458.jpg
# 13705
# Uploading file:processed/dandelion/train/img615.jpg
# 11922
# Uploading file:processed/dandelion/train/img616.jpg
# 17256
# Uploading file:processed/dandelion/train/img617.jpg
# 15128
# Uploading file:processed/roses/train/img459.jpg
# 24370
# Uploading file:processed/daisy/train/img430.jpg
# 14994
# Uploading file:processed/dandelion/train/img618.jpg
# 9829
# Uploading file:processed/dandelion/train/img619.jpg
# 11758
# Uploading file:processed/daisy/train/img431.jpg
# 14796
# Uploading file:processed/dandelion/train/img620.jpg
# 7525
# Uploading file:processed/roses/train/img460.jpg
# 9173
# Uploading file:processed/roses/train/img461.jpg
# 24103
# Uploading file:processed/dandelion/train/img621.jpg
# 21968
# Uploading file:processed/daisy/train/img432.jpg
# 15966
# Uploading file:processed/daisy/train/img433.jpg
# 12436
# Uploading file:processed/daisy/train/img434.jpg
# 16092
# Uploading file:processed/daisy/train/img435.jpg
# 16439
# Uploading file:processed/daisy/train/img436.jpg
# 20709
# Uploading file:processed/daisy/train/img437.jpg
# 17793
# Uploading file:processed/daisy/train/img438.jpg
# 25628
# Uploading file:processed/dandelion/train/img622.jpg
# 9099
# Uploading file:processed/dandelion/train/img623.jpg
# 8885
# Uploading file:processed/dandelion/train/img624.jpg
# 15631
# Uploading file:processed/dandelion/train/img625.jpg
# 13947
# Uploading file:processed/dandelion/train/img626.jpg
# 11646

# %%
upload_df_to_s3(test, "test")
# Out:
# Uploading to bucket:nanonets-platform-task
# Uploading file:processed/dandelion/test/img627.jpg
# 17473
# Uploading file:processed/sunflowers/test/img293.jpg
# 28448
# Uploading file:processed/daisy/test/img439.jpg
# 17000
# Uploading file:processed/daisy/test/img440.jpg
# 19325
# Uploading file:processed/roses/test/img462.jpg
# 10862
# Uploading file:processed/sunflowers/test/img294.jpg
# 36659
# Uploading file:processed/sunflowers/test/img295.jpg
# 9072
# Uploading file:processed/roses/test/img463.jpg
# 15799
# Uploading file:processed/dandelion/test/img628.jpg
# 19035
# Uploading file:processed/dandelion/test/img629.jpg
# 20038
# Uploading file:processed/sunflowers/test/img296.jpg
# 40453
# Uploading file:processed/roses/test/img464.jpg
# 11422
# Uploading file:processed/roses/test/img465.jpg
# 14726
# Uploading file:processed/roses/test/img466.jpg
# 12012
# Uploading file:processed/dandelion/test/img630.jpg
# 15852
# Uploading file:processed/dandelion/test/img631.jpg
# 14229
# Uploading file:processed/daisy/test/img441.jpg
# 24493
# Uploading file:processed/roses/test/img467.jpg
# 17036
# Uploading file:processed/roses/test/img468.jpg
# 30781
# Uploading file:processed/sunflowers/test/img297.jpg
# 20971
# Uploading file:processed/dandelion/test/img632.jpg
# 18317
# Uploading file:processed/roses/test/img469.jpg
# 24058
# Uploading file:processed/roses/test/img470.jpg
# 12730
# Uploading file:processed/daisy/test/img442.jpg
# 18834
# Uploading file:processed/roses/test/img471.jpg
# 13606
# Uploading file:processed/dandelion/test/img633.jpg
# 14335
# Uploading file:processed/sunflowers/test/img298.jpg
# 34398
# Uploading file:processed/dandelion/test/img634.jpg
# 14523
# Uploading file:processed/sunflowers/test/img299.jpg
# 28082
# Uploading file:processed/daisy/test/img443.jpg
# 23311
# Uploading file:processed/sunflowers/test/img300.jpg
# 21321
# Uploading file:processed/dandelion/test/img635.jpg
# 26000
# Uploading file:processed/roses/test/img472.jpg
# 17416
# Uploading file:processed/dandelion/test/img636.jpg
# 12293
# Uploading file:processed/dandelion/test/img637.jpg
# 14822
# Uploading file:processed/dandelion/test/img638.jpg
# 20583
# Uploading file:processed/sunflowers/test/img301.jpg
# 33239
# Uploading file:processed/roses/test/img473.jpg
# 20071
# Uploading file:processed/roses/test/img474.jpg
# 9855
# Uploading file:processed/dandelion/test/img639.jpg
# 40062
# Uploading file:processed/dandelion/test/img640.jpg
# 14622
# Uploading file:processed/dandelion/test/img641.jpg
# 25981
# Uploading file:processed/daisy/test/img444.jpg
# 14187
# Uploading file:processed/sunflowers/test/img302.jpg
# 26685
# Uploading file:processed/sunflowers/test/img303.jpg
# 26210
# Uploading file:processed/dandelion/test/img642.jpg
# 14252
# Uploading file:processed/sunflowers/test/img304.jpg
# 13483
# Uploading file:processed/daisy/test/img445.jpg
# 6685
# Uploading file:processed/daisy/test/img446.jpg
# 15299
# Uploading file:processed/roses/test/img475.jpg
# 26324
# Uploading file:processed/dandelion/test/img643.jpg
# 30225
# Uploading file:processed/dandelion/test/img644.jpg
# 11510
# Uploading file:processed/sunflowers/test/img305.jpg
# 29899
# Uploading file:processed/roses/test/img476.jpg
# 15032
# Uploading file:processed/dandelion/test/img645.jpg
# 10679
# Uploading file:processed/roses/test/img477.jpg
# 12311
# Uploading file:processed/sunflowers/test/img306.jpg
# 32833
# Uploading file:processed/sunflowers/test/img307.jpg
# 21841
# Uploading file:processed/dandelion/test/img646.jpg
# 23919
# Uploading file:processed/roses/test/img478.jpg
# 16856
# Uploading file:processed/sunflowers/test/img308.jpg
# 15356
# Uploading file:processed/dandelion/test/img647.jpg
# 13184
# Uploading file:processed/daisy/test/img447.jpg
# 26297
# Uploading file:processed/dandelion/test/img648.jpg
# 14233
# Uploading file:processed/dandelion/test/img649.jpg
# 13683
# Uploading file:processed/sunflowers/test/img309.jpg
# 31197
# Uploading file:processed/daisy/test/img448.jpg
# 13327
# Uploading file:processed/sunflowers/test/img310.jpg
# 17512
# Uploading file:processed/daisy/test/img449.jpg
# 12468
# Uploading file:processed/daisy/test/img450.jpg
# 8661
# Uploading file:processed/dandelion/test/img650.jpg
# 14670
# Uploading file:processed/dandelion/test/img651.jpg
# 13922
# Uploading file:processed/dandelion/test/img652.jpg
# 10181
# Uploading file:processed/dandelion/test/img653.jpg
# 13878
# Uploading file:processed/sunflowers/test/img311.jpg
# 34406
# Uploading file:processed/sunflowers/test/img312.jpg
# 30359
# Uploading file:processed/roses/test/img479.jpg
# 25224
# Uploading file:processed/sunflowers/test/img313.jpg
# 34593
# Uploading file:processed/daisy/test/img451.jpg
# 17220
# Uploading file:processed/sunflowers/test/img314.jpg
# 24904
# Uploading file:processed/daisy/test/img452.jpg
# 8857
# Uploading file:processed/dandelion/test/img654.jpg
# 14659
# Uploading file:processed/daisy/test/img453.jpg
# 11140
# Uploading file:processed/sunflowers/test/img315.jpg
# 28479
# Uploading file:processed/roses/test/img480.jpg
# 12455
# Uploading file:processed/daisy/test/img454.jpg
# 10646
# Uploading file:processed/daisy/test/img455.jpg
# 11467
# Uploading file:processed/dandelion/test/img655.jpg
# 9316
# Uploading file:processed/daisy/test/img456.jpg
# 16880
# Uploading file:processed/roses/test/img481.jpg
# 13033
# Uploading file:processed/dandelion/test/img656.jpg
# 19651
# Uploading file:processed/roses/test/img482.jpg
# 9479
# Uploading file:processed/daisy/test/img457.jpg
# 19185
# Uploading file:processed/sunflowers/test/img316.jpg
# 26833
# Uploading file:processed/roses/test/img483.jpg
# 21791
# Uploading file:processed/sunflowers/test/img317.jpg
# 22949
# Uploading file:processed/dandelion/test/img657.jpg
# 7197
# Uploading file:processed/dandelion/test/img658.jpg
# 15682
# Uploading file:processed/dandelion/test/img659.jpg
# 19379
# Uploading file:processed/sunflowers/test/img318.jpg
# 24048
# Uploading file:processed/sunflowers/test/img319.jpg
# 16238
# Uploading file:processed/roses/test/img484.jpg
# 14731
# Uploading file:processed/dandelion/test/img660.jpg
# 7745
# Uploading file:processed/dandelion/test/img661.jpg
# 14258
# Uploading file:processed/dandelion/test/img662.jpg
# 26376
# Uploading file:processed/roses/test/img485.jpg
# 34076
# Uploading file:processed/daisy/test/img458.jpg
# 12892
# Uploading file:processed/daisy/test/img459.jpg
# 20730
# Uploading file:processed/daisy/test/img460.jpg
# 17499
# Uploading file:processed/roses/test/img486.jpg
# 32432
# Uploading file:processed/dandelion/test/img663.jpg
# 9461
# Uploading file:processed/dandelion/test/img664.jpg
# 23598
# Uploading file:processed/daisy/test/img461.jpg
# 20245
# Uploading file:processed/roses/test/img487.jpg
# 11879
# Uploading file:processed/daisy/test/img462.jpg
# 47613
# Uploading file:processed/roses/test/img488.jpg
# 22110
# Uploading file:processed/dandelion/test/img665.jpg
# 12333
# Uploading file:processed/roses/test/img489.jpg
# 16990
# Uploading file:processed/dandelion/test/img666.jpg
# 11796
# Uploading file:processed/dandelion/test/img667.jpg
# 16118
# Uploading file:processed/sunflowers/test/img320.jpg
# 17113
# Uploading file:processed/daisy/test/img463.jpg
# 21922
# Uploading file:processed/daisy/test/img464.jpg
# 9981
# Uploading file:processed/daisy/test/img465.jpg
# 16198
# Uploading file:processed/dandelion/test/img668.jpg
# 9929
# Uploading file:processed/daisy/test/img466.jpg
# 16129
# Uploading file:processed/daisy/test/img467.jpg
# 9575
# Uploading file:processed/dandelion/test/img669.jpg
# 12419
# Uploading file:processed/dandelion/test/img670.jpg
# 9046
# Uploading file:processed/daisy/test/img468.jpg
# 8100
# Uploading file:processed/roses/test/img490.jpg
# 17278
# Uploading file:processed/sunflowers/test/img321.jpg
# 16677
# Uploading file:processed/dandelion/test/img671.jpg
# 13789
# Uploading file:processed/dandelion/test/img672.jpg
# 11987
# Uploading file:processed/daisy/test/img469.jpg
# 14216
# Uploading file:processed/sunflowers/test/img322.jpg
# 20299
# Uploading file:processed/roses/test/img491.jpg
# 22328
# Uploading file:processed/dandelion/test/img673.jpg
# 6951
# Uploading file:processed/roses/test/img492.jpg
# 24049
# Uploading file:processed/sunflowers/test/img323.jpg
# 30517
# Uploading file:processed/dandelion/test/img674.jpg
# 23417
# Uploading file:processed/sunflowers/test/img324.jpg
# 32989
# Uploading file:processed/daisy/test/img470.jpg
# 15065
# Uploading file:processed/roses/test/img493.jpg
# 16257
# Uploading file:processed/dandelion/test/img675.jpg
# 15950
# Uploading file:processed/daisy/test/img471.jpg
# 15959
# Uploading file:processed/roses/test/img494.jpg
# 19387
# Uploading file:processed/dandelion/test/img676.jpg
# 14167
# Uploading file:processed/daisy/test/img472.jpg
# 22064
# Uploading file:processed/daisy/test/img473.jpg
# 16710
# Uploading file:processed/dandelion/test/img677.jpg
# 19644
# Uploading file:processed/dandelion/test/img678.jpg
# 13087
# Uploading file:processed/roses/test/img495.jpg
# 10131
# Uploading file:processed/daisy/test/img474.jpg
# 20486
# Uploading file:processed/roses/test/img496.jpg
# 16509
# Uploading file:processed/dandelion/test/img679.jpg
# 18952
# Uploading file:processed/dandelion/test/img680.jpg
# 17368
# Uploading file:processed/daisy/test/img475.jpg
# 28056
# Uploading file:processed/dandelion/test/img681.jpg
# 15224
# Uploading file:processed/dandelion/test/img682.jpg
# 22426
# Uploading file:processed/roses/test/img497.jpg
# 39152
# Uploading file:processed/dandelion/test/img683.jpg
# 17501
# Uploading file:processed/dandelion/test/img684.jpg
# 9200
# Uploading file:processed/sunflowers/test/img325.jpg
# 27844
# Uploading file:processed/dandelion/test/img685.jpg
# 12923
# Uploading file:processed/roses/test/img498.jpg
# 20699
# Uploading file:processed/dandelion/test/img686.jpg
# 8995
# Uploading file:processed/dandelion/test/img687.jpg
# 11760
# Uploading file:processed/dandelion/test/img688.jpg
# 23664
# Uploading file:processed/sunflowers/test/img326.jpg
# 25586
# Uploading file:processed/dandelion/test/img689.jpg
# 15943
# Uploading file:processed/dandelion/test/img690.jpg
# 11005
# Uploading file:processed/dandelion/test/img691.jpg
# 16636
# Uploading file:processed/roses/test/img499.jpg
# 8393
# Uploading file:processed/dandelion/test/img692.jpg
# 22047
# Uploading file:processed/daisy/test/img476.jpg
# 30085
# Uploading file:processed/roses/test/img500.jpg
# 17581
# Uploading file:processed/roses/test/img501.jpg
# 17733
# Uploading file:processed/dandelion/test/img693.jpg
# 18453
# Uploading file:processed/dandelion/test/img694.jpg
# 14358
# Uploading file:processed/dandelion/test/img695.jpg
# 11250
# Uploading file:processed/daisy/test/img477.jpg
# 20935
# Uploading file:processed/roses/test/img502.jpg
# 27608
# Uploading file:processed/dandelion/test/img696.jpg
# 24447
# Uploading file:processed/dandelion/test/img697.jpg
# 34689
# Uploading file:processed/roses/test/img503.jpg
# 11279
# Uploading file:processed/daisy/test/img478.jpg
# 19224
# Uploading file:processed/roses/test/img504.jpg
# 17941
# Uploading file:processed/roses/test/img505.jpg
# 25029
# Uploading file:processed/daisy/test/img479.jpg
# 19753
# Uploading file:processed/dandelion/test/img698.jpg
# 16794
# Uploading file:processed/dandelion/test/img699.jpg
# 12240
# Uploading file:processed/dandelion/test/img700.jpg
# 30978
# Uploading file:processed/daisy/test/img480.jpg
# 31206
# Uploading file:processed/dandelion/test/img701.jpg
# 8423
# Uploading file:processed/daisy/test/img481.jpg
# 18751
# Uploading file:processed/daisy/test/img482.jpg
# 13484
# Uploading file:processed/dandelion/test/img702.jpg
# 18192
# Uploading file:processed/sunflowers/test/img327.jpg
# 20304
# Uploading file:processed/daisy/test/img483.jpg
# 33030
# Uploading file:processed/daisy/test/img484.jpg
# 14860
# Uploading file:processed/dandelion/test/img703.jpg
# 16382
# Uploading file:processed/roses/test/img506.jpg
# 17033
# Uploading file:processed/daisy/test/img485.jpg
# 18099
# Uploading file:processed/sunflowers/test/img328.jpg
# 26477
# Uploading file:processed/daisy/test/img486.jpg
# 6784
# Uploading file:processed/dandelion/test/img704.jpg
# 23243
# Uploading file:processed/roses/test/img507.jpg
# 11885
# Uploading file:processed/dandelion/test/img705.jpg
# 21241
# Uploading file:processed/dandelion/test/img706.jpg
# 11399
# Uploading file:processed/roses/test/img508.jpg
# 33400
# Uploading file:processed/daisy/test/img487.jpg
# 11357
# Uploading file:processed/daisy/test/img488.jpg
# 13772
# Uploading file:processed/dandelion/test/img707.jpg
# 16315
# Uploading file:processed/dandelion/test/img708.jpg
# 12967
# Uploading file:processed/roses/test/img509.jpg
# 31795
# Uploading file:processed/dandelion/test/img709.jpg
# 14817
# Uploading file:processed/daisy/test/img489.jpg
# 15199
# Uploading file:processed/sunflowers/test/img329.jpg
# 33791
# Uploading file:processed/sunflowers/test/img330.jpg
# 23636
# Uploading file:processed/dandelion/test/img710.jpg
# 17704
# Uploading file:processed/roses/test/img510.jpg
# 15469
# Uploading file:processed/daisy/test/img490.jpg
# 13245
# Uploading file:processed/daisy/test/img491.jpg
# 8602
# Uploading file:processed/roses/test/img511.jpg
# 13178
# Uploading file:processed/dandelion/test/img711.jpg
# 24766
# Uploading file:processed/sunflowers/test/img331.jpg
# 20280
# Uploading file:processed/dandelion/test/img712.jpg
# 28473
# Uploading file:processed/dandelion/test/img713.jpg
# 19379
# Uploading file:processed/dandelion/test/img714.jpg
# 20352
# Uploading file:processed/dandelion/test/img715.jpg
# 9863
# Uploading file:processed/daisy/test/img492.jpg
# 16274
# Uploading file:processed/roses/test/img512.jpg
# 16071
# Uploading file:processed/daisy/test/img493.jpg
# 9856
# Uploading file:processed/dandelion/test/img716.jpg
# 26364
# Uploading file:processed/daisy/test/img494.jpg
# 9658
# Uploading file:processed/daisy/test/img495.jpg
# 23161
# Uploading file:processed/roses/test/img513.jpg
# 24774
# Uploading file:processed/dandelion/test/img717.jpg
# 12791
# Uploading file:processed/sunflowers/test/img332.jpg
# 17261
# Uploading file:processed/dandelion/test/img718.jpg
# 11939
# Uploading file:processed/dandelion/test/img719.jpg
# 16857
# Uploading file:processed/sunflowers/test/img333.jpg
# 28912
# Uploading file:processed/sunflowers/test/img334.jpg
# 16259
# Uploading file:processed/sunflowers/test/img335.jpg
# 22880
# Uploading file:processed/roses/test/img514.jpg
# 20219
# Uploading file:processed/daisy/test/img496.jpg
# 9459
# Uploading file:processed/dandelion/test/img720.jpg
# 30428
# Uploading file:processed/roses/test/img515.jpg
# 26894
# Uploading file:processed/daisy/test/img497.jpg
# 20214
# Uploading file:processed/dandelion/test/img721.jpg
# 17261
# Uploading file:processed/dandelion/test/img722.jpg
# 12986
# Uploading file:processed/dandelion/test/img723.jpg
# 10302
# Uploading file:processed/roses/test/img516.jpg
# 19382
# Uploading file:processed/daisy/test/img498.jpg
# 7373
# Uploading file:processed/roses/test/img517.jpg
# 16598
# Uploading file:processed/dandelion/test/img724.jpg
# 17893
# Uploading file:processed/daisy/test/img499.jpg
# 36444
# Uploading file:processed/roses/test/img518.jpg
# 8873
# Uploading file:processed/sunflowers/test/img336.jpg
# 24637

# %%
upload_df_to_s3(validate, "validate")
# Out:
# Uploading to bucket:nanonets-platform-task
# Uploading file:processed/dandelion/validate/img725.jpg
# 17840
# Uploading file:processed/daisy/validate/img500.jpg
# 16168
# Uploading file:processed/roses/validate/img519.jpg
# 17403
# Uploading file:processed/roses/validate/img520.jpg
# 12147
# Uploading file:processed/sunflowers/validate/img337.jpg
# 20354
# Uploading file:processed/roses/validate/img521.jpg
# 10938
# Uploading file:processed/daisy/validate/img501.jpg
# 18120
# Uploading file:processed/dandelion/validate/img726.jpg
# 14135
# Uploading file:processed/dandelion/validate/img727.jpg
# 18113
# Uploading file:processed/dandelion/validate/img728.jpg
# 21389
# Uploading file:processed/sunflowers/validate/img338.jpg
# 22971
# Uploading file:processed/daisy/validate/img502.jpg
# 26114
# Uploading file:processed/daisy/validate/img503.jpg
# 16239
# Uploading file:processed/dandelion/validate/img729.jpg
# 14605
# Uploading file:processed/sunflowers/validate/img339.jpg
# 28768
# Uploading file:processed/roses/validate/img522.jpg
# 16592
# Uploading file:processed/dandelion/validate/img730.jpg
# 47678
# Uploading file:processed/roses/validate/img523.jpg
# 18119
# Uploading file:processed/daisy/validate/img504.jpg
# 9286
# Uploading file:processed/roses/validate/img524.jpg
# 8889
# Uploading file:processed/sunflowers/validate/img340.jpg
# 19264
# Uploading file:processed/sunflowers/validate/img341.jpg
# 19183
# Uploading file:processed/dandelion/validate/img731.jpg
# 7132
# Uploading file:processed/dandelion/validate/img732.jpg
# 16271
# Uploading file:processed/dandelion/validate/img733.jpg
# 9394
# Uploading file:processed/daisy/validate/img505.jpg
# 12478
# Uploading file:processed/roses/validate/img525.jpg
# 25271
# Uploading file:processed/dandelion/validate/img734.jpg
# 20659
# Uploading file:processed/daisy/validate/img506.jpg
# 12222
# Uploading file:processed/roses/validate/img526.jpg
# 12419
# Uploading file:processed/dandelion/validate/img735.jpg
# 17917
# Uploading file:processed/dandelion/validate/img736.jpg
# 14769
# Uploading file:processed/daisy/validate/img507.jpg
# 22644
# Uploading file:processed/dandelion/validate/img737.jpg
# 19722
# Uploading file:processed/dandelion/validate/img738.jpg
# 18554
# Uploading file:processed/daisy/validate/img508.jpg
# 17625
# Uploading file:processed/sunflowers/validate/img342.jpg
# 16186
# Uploading file:processed/sunflowers/validate/img343.jpg
# 20725
# Uploading file:processed/daisy/validate/img509.jpg
# 16993
# Uploading file:processed/roses/validate/img527.jpg
# 26225
# Uploading file:processed/daisy/validate/img510.jpg
# 16212
# Uploading file:processed/dandelion/validate/img739.jpg
# 7233
# Uploading file:processed/dandelion/validate/img740.jpg
# 12009
# Uploading file:processed/roses/validate/img528.jpg
# 9697
# Uploading file:processed/roses/validate/img529.jpg
# 21450
# Uploading file:processed/dandelion/validate/img741.jpg
# 17252
# Uploading file:processed/roses/validate/img530.jpg
# 21641
# Uploading file:processed/sunflowers/validate/img344.jpg
# 20814
# Uploading file:processed/dandelion/validate/img742.jpg
# 21972
# Uploading file:processed/dandelion/validate/img743.jpg
# 22499
# Uploading file:processed/daisy/validate/img511.jpg
# 20055
# Uploading file:processed/roses/validate/img531.jpg
# 10220
# Uploading file:processed/roses/validate/img532.jpg
# 16575
# Uploading file:processed/roses/validate/img533.jpg
# 27663
# Uploading file:processed/dandelion/validate/img744.jpg
# 17657
# Uploading file:processed/daisy/validate/img512.jpg
# 10609
# Uploading file:processed/sunflowers/validate/img345.jpg
# 23557
# Uploading file:processed/sunflowers/validate/img346.jpg
# 27460
# Uploading file:processed/daisy/validate/img513.jpg
# 18436
# Uploading file:processed/daisy/validate/img514.jpg
# 23181
# Uploading file:processed/roses/validate/img534.jpg
# 27895
# Uploading file:processed/dandelion/validate/img745.jpg
# 17869
# Uploading file:processed/roses/validate/img535.jpg
# 30626
# Uploading file:processed/sunflowers/validate/img347.jpg
# 22023
# Uploading file:processed/daisy/validate/img515.jpg
# 24404
# Uploading file:processed/roses/validate/img536.jpg
# 15009
# Uploading file:processed/sunflowers/validate/img348.jpg
# 42406
# Uploading file:processed/dandelion/validate/img746.jpg
# 7785
# Uploading file:processed/sunflowers/validate/img349.jpg
# 33483
# Uploading file:processed/daisy/validate/img516.jpg
# 21369
# Uploading file:processed/daisy/validate/img517.jpg
# 10170
# Uploading file:processed/roses/validate/img537.jpg
# 13822
# Uploading file:processed/roses/validate/img538.jpg
# 26594
# Uploading file:processed/roses/validate/img539.jpg
# 13274
# Uploading file:processed/roses/validate/img540.jpg
# 29136
# Uploading file:processed/roses/validate/img541.jpg
# 12229
# Uploading file:processed/daisy/validate/img518.jpg
# 7570
# Uploading file:processed/roses/validate/img542.jpg
# 15190
# Uploading file:processed/sunflowers/validate/img350.jpg
# 37505
# Uploading file:processed/roses/validate/img543.jpg
# 14889
# Uploading file:processed/daisy/validate/img519.jpg
# 15094
# Uploading file:processed/roses/validate/img544.jpg
# 36853
# Uploading file:processed/dandelion/validate/img747.jpg
# 12465
# Uploading file:processed/daisy/validate/img520.jpg
# 21097
# Uploading file:processed/dandelion/validate/img748.jpg
# 6424
# Uploading file:processed/roses/validate/img545.jpg
# 30852
# Uploading file:processed/daisy/validate/img521.jpg
# 26208
# Uploading file:processed/dandelion/validate/img749.jpg
# 8895
# Uploading file:processed/daisy/validate/img522.jpg
# 18223
# Uploading file:processed/dandelion/validate/img750.jpg
# 35990
# Uploading file:processed/roses/validate/img546.jpg
# 23536
# Uploading file:processed/dandelion/validate/img751.jpg
# 35184
# Uploading file:processed/sunflowers/validate/img351.jpg
# 25238
# Uploading file:processed/roses/validate/img547.jpg
# 25549
# Uploading file:processed/roses/validate/img548.jpg
# 26448
# Uploading file:processed/sunflowers/validate/img352.jpg
# 22154
# Uploading file:processed/dandelion/validate/img752.jpg
# 16018
# Uploading file:processed/dandelion/validate/img753.jpg
# 8635
# Uploading file:processed/daisy/validate/img523.jpg
# 18278
# Uploading file:processed/roses/validate/img549.jpg
# 16188
# Uploading file:processed/roses/validate/img550.jpg
# 13237
# Uploading file:processed/dandelion/validate/img754.jpg
# 12903
# Uploading file:processed/roses/validate/img551.jpg
# 12842
# Uploading file:processed/sunflowers/validate/img353.jpg
# 20270
# Uploading file:processed/daisy/validate/img524.jpg
# 11116
# Uploading file:processed/sunflowers/validate/img354.jpg
# 28828
# Uploading file:processed/sunflowers/validate/img355.jpg
# 21000
# Uploading file:processed/daisy/validate/img525.jpg
# 38494
# Uploading file:processed/daisy/validate/img526.jpg
# 15613
# Uploading file:processed/sunflowers/validate/img356.jpg
# 29084
# Uploading file:processed/sunflowers/validate/img357.jpg
# 24001
# Uploading file:processed/sunflowers/validate/img358.jpg
# 21287
# Uploading file:processed/sunflowers/validate/img359.jpg
# 17708
# Uploading file:processed/dandelion/validate/img755.jpg
# 18667
# Uploading file:processed/roses/validate/img552.jpg
# 18785
# Uploading file:processed/dandelion/validate/img756.jpg
# 18614
# Uploading file:processed/daisy/validate/img527.jpg
# 20375
# Uploading file:processed/dandelion/validate/img757.jpg
# 13171
# Uploading file:processed/daisy/validate/img528.jpg
# 8735
# Uploading file:processed/dandelion/validate/img758.jpg
# 15441
# Uploading file:processed/roses/validate/img553.jpg
# 18703
# Uploading file:processed/dandelion/validate/img759.jpg
# 17830
# Uploading file:processed/daisy/validate/img529.jpg
# 13588
# Uploading file:processed/daisy/validate/img530.jpg
# 15856
# Uploading file:processed/dandelion/validate/img760.jpg
# 8069
# Uploading file:processed/sunflowers/validate/img360.jpg
# 29210
# Uploading file:processed/dandelion/validate/img761.jpg
# 14966
# Uploading file:processed/sunflowers/validate/img361.jpg
# 13154
# Uploading file:processed/dandelion/validate/img762.jpg
# 19325
# Uploading file:processed/dandelion/validate/img763.jpg
# 18420
# Uploading file:processed/dandelion/validate/img764.jpg
# 24901
# Uploading file:processed/daisy/validate/img531.jpg
# 13854
# Uploading file:processed/dandelion/validate/img765.jpg
# 17056
# Uploading file:processed/roses/validate/img554.jpg
# 18627
# Uploading file:processed/dandelion/validate/img766.jpg
# 18009
# Uploading file:processed/roses/validate/img555.jpg
# 21385
# Uploading file:processed/dandelion/validate/img767.jpg
# 18391
# Uploading file:processed/sunflowers/validate/img362.jpg
# 25141
# Uploading file:processed/sunflowers/validate/img363.jpg
# 36726
# Uploading file:processed/daisy/validate/img532.jpg
# 24557
# Uploading file:processed/sunflowers/validate/img364.jpg
# 24510
# Uploading file:processed/sunflowers/validate/img365.jpg
# 27445
# Uploading file:processed/roses/validate/img556.jpg
# 17384
# Uploading file:processed/dandelion/validate/img768.jpg
# 15063
# Uploading file:processed/dandelion/validate/img769.jpg
# 18140
# Uploading file:processed/roses/validate/img557.jpg
# 33251
# Uploading file:processed/daisy/validate/img533.jpg
# 20293
# Uploading file:processed/roses/validate/img558.jpg
# 21985
# Uploading file:processed/daisy/validate/img534.jpg
# 18584
# Uploading file:processed/dandelion/validate/img770.jpg
# 22482
# Uploading file:processed/roses/validate/img559.jpg
# 37221
# Uploading file:processed/dandelion/validate/img771.jpg
# 12397
# Uploading file:processed/sunflowers/validate/img366.jpg
# 25976
# Uploading file:processed/roses/validate/img560.jpg
# 16480
# Uploading file:processed/dandelion/validate/img772.jpg
# 9053
# Uploading file:processed/daisy/validate/img535.jpg
# 8069
# Uploading file:processed/dandelion/validate/img773.jpg
# 15298
# Uploading file:processed/dandelion/validate/img774.jpg
# 18461
# Uploading file:processed/daisy/validate/img536.jpg
# 12283
# Uploading file:processed/daisy/validate/img537.jpg
# 19387
# Uploading file:processed/dandelion/validate/img775.jpg
# 24487
# Uploading file:processed/sunflowers/validate/img367.jpg
# 26871
# Uploading file:processed/daisy/validate/img538.jpg
# 44735
# Uploading file:processed/daisy/validate/img539.jpg
# 35420
# Uploading file:processed/roses/validate/img561.jpg
# 12779
# Uploading file:processed/dandelion/validate/img776.jpg
# 17158
# Uploading file:processed/dandelion/validate/img777.jpg
# 13573
# Uploading file:processed/roses/validate/img562.jpg
# 9538
# Uploading file:processed/daisy/validate/img540.jpg
# 20718
# Uploading file:processed/dandelion/validate/img778.jpg
# 21115
# Uploading file:processed/roses/validate/img563.jpg
# 18218
# Uploading file:processed/sunflowers/validate/img368.jpg
# 30293
# Uploading file:processed/roses/validate/img564.jpg
# 22105
# Uploading file:processed/daisy/validate/img541.jpg
# 26814
# Uploading file:processed/daisy/validate/img542.jpg
# 11063
# Uploading file:processed/dandelion/validate/img779.jpg
# 13371
# Uploading file:processed/sunflowers/validate/img369.jpg
# 48631
# Uploading file:processed/daisy/validate/img543.jpg
# 20945
# Uploading file:processed/roses/validate/img565.jpg
# 20222
# Uploading file:processed/sunflowers/validate/img370.jpg
# 19143
# Uploading file:processed/roses/validate/img566.jpg
# 28342
# Uploading file:processed/roses/validate/img567.jpg
# 16587
# Uploading file:processed/dandelion/validate/img780.jpg
# 16458
# Uploading file:processed/dandelion/validate/img781.jpg
# 20021
# Uploading file:processed/daisy/validate/img544.jpg
# 21471
# Uploading file:processed/dandelion/validate/img782.jpg
# 14767
# Uploading file:processed/dandelion/validate/img783.jpg
# 25535
# Uploading file:processed/daisy/validate/img545.jpg
# 12584
# Uploading file:processed/roses/validate/img568.jpg
# 21625
# Uploading file:processed/dandelion/validate/img784.jpg
# 22911
# Uploading file:processed/roses/validate/img569.jpg
# 20233
# Uploading file:processed/dandelion/validate/img785.jpg
# 6796
# Uploading file:processed/dandelion/validate/img786.jpg
# 12793
# Uploading file:processed/dandelion/validate/img787.jpg
# 11347
# Uploading file:processed/dandelion/validate/img788.jpg
# 19969
# Uploading file:processed/daisy/validate/img546.jpg
# 11782
# Uploading file:processed/dandelion/validate/img789.jpg
# 12504
# Uploading file:processed/dandelion/validate/img790.jpg
# 7185
# Uploading file:processed/sunflowers/validate/img371.jpg
# 20395
# Uploading file:processed/dandelion/validate/img791.jpg
# 14584
# Uploading file:processed/roses/validate/img570.jpg
# 18223
# Uploading file:processed/daisy/validate/img547.jpg
# 29695
# Uploading file:processed/dandelion/validate/img792.jpg
# 12005
# Uploading file:processed/dandelion/validate/img793.jpg
# 9886
# Uploading file:processed/dandelion/validate/img794.jpg
# 15032
# Uploading file:processed/daisy/validate/img548.jpg
# 11713
# Uploading file:processed/roses/validate/img571.jpg
# 23892
# Uploading file:processed/daisy/validate/img549.jpg
# 24146
# Uploading file:processed/roses/validate/img572.jpg
# 14061
# Uploading file:processed/daisy/validate/img550.jpg
# 18651
# Uploading file:processed/dandelion/validate/img795.jpg
# 11908
# Uploading file:processed/daisy/validate/img551.jpg
# 13261
# Uploading file:processed/sunflowers/validate/img372.jpg
# 31908
# Uploading file:processed/roses/validate/img573.jpg
# 13898
# Uploading file:processed/roses/validate/img574.jpg
# 27722
# Uploading file:processed/daisy/validate/img552.jpg
# 10931
# Uploading file:processed/roses/validate/img575.jpg
# 18327
# Uploading file:processed/roses/validate/img576.jpg
# 10707
# Uploading file:processed/daisy/validate/img553.jpg
# 10801
# Uploading file:processed/roses/validate/img577.jpg
# 25850
# Uploading file:processed/sunflowers/validate/img373.jpg
# 13671
# Uploading file:processed/dandelion/validate/img796.jpg
# 17780
# Uploading file:processed/dandelion/validate/img797.jpg
# 20065
# Uploading file:processed/sunflowers/validate/img374.jpg
# 21894
# Uploading file:processed/dandelion/validate/img798.jpg
# 12228
# Uploading file:processed/dandelion/validate/img799.jpg
# 19557
# Uploading file:processed/roses/validate/img578.jpg
# 19225
# Uploading file:processed/daisy/validate/img554.jpg
# 22437
# Uploading file:processed/daisy/validate/img555.jpg
# 14635
# Uploading file:processed/sunflowers/validate/img375.jpg
# 29543
# Uploading file:processed/sunflowers/validate/img376.jpg
# 18581
# Uploading file:processed/daisy/validate/img556.jpg
# 15143
# Uploading file:processed/dandelion/validate/img800.jpg
# 16931
# Uploading file:processed/dandelion/validate/img801.jpg
# 15339
# Uploading file:processed/roses/validate/img579.jpg
# 21901
# Uploading file:processed/roses/validate/img580.jpg
# 17360
# Uploading file:processed/dandelion/validate/img802.jpg
# 16759
# Uploading file:processed/dandelion/validate/img803.jpg
# 6724
# Uploading file:processed/daisy/validate/img557.jpg
# 26444
# Uploading file:processed/dandelion/validate/img804.jpg
# 13036
# Uploading file:processed/dandelion/validate/img805.jpg
# 14980
# Uploading file:processed/dandelion/validate/img806.jpg
# 21417
# Uploading file:processed/daisy/validate/img558.jpg
# 17962
# Uploading file:processed/dandelion/validate/img807.jpg
# 18117
# Uploading file:processed/sunflowers/validate/img377.jpg
# 23697
# Uploading file:processed/dandelion/validate/img808.jpg
# 19187
# Uploading file:processed/daisy/validate/img559.jpg
# 17854
# Uploading file:processed/daisy/validate/img560.jpg
# 24620
# Uploading file:processed/sunflowers/validate/img378.jpg
# 16443
# Uploading file:processed/sunflowers/validate/img379.jpg
# 28399
# Uploading file:processed/roses/validate/img581.jpg
# 11989
# Uploading file:processed/daisy/validate/img561.jpg
# 42074
# Uploading file:processed/roses/validate/img582.jpg
# 16192
# Uploading file:processed/dandelion/validate/img809.jpg
# 19776
# Uploading file:processed/dandelion/validate/img810.jpg
# 13915
# Uploading file:processed/dandelion/validate/img811.jpg
# 26292
# Uploading file:processed/daisy/validate/img562.jpg
# 8120
# Uploading file:processed/daisy/validate/img563.jpg
# 23498
# Uploading file:processed/roses/validate/img583.jpg
# 8209
# Uploading file:processed/sunflowers/validate/img380.jpg
# 10514
# Uploading file:processed/roses/validate/img584.jpg
# 17080
# Uploading file:processed/dandelion/validate/img812.jpg
# 8258
# Uploading file:processed/daisy/validate/img564.jpg
# 16483
# Uploading file:processed/sunflowers/validate/img381.jpg
# 26797
# Uploading file:processed/roses/validate/img585.jpg
# 19226
# Uploading file:processed/dandelion/validate/img813.jpg
# 17952
# Uploading file:processed/sunflowers/validate/img382.jpg
# 22194
# Uploading file:processed/dandelion/validate/img814.jpg
# 6530
# Uploading file:processed/daisy/validate/img565.jpg
# 25026
# Uploading file:processed/roses/validate/img586.jpg
# 16616
# Uploading file:processed/daisy/validate/img566.jpg
# 10431
# Uploading file:processed/roses/validate/img587.jpg
# 9869
# Uploading file:processed/dandelion/validate/img815.jpg
# 33832
# Uploading file:processed/daisy/validate/img567.jpg
# 11994
# Uploading file:processed/daisy/validate/img568.jpg
# 8719
# Uploading file:processed/roses/validate/img588.jpg
# 11797
# Uploading file:processed/sunflowers/validate/img383.jpg
# 34250
# Uploading file:processed/roses/validate/img589.jpg
# 14296
# Uploading file:processed/dandelion/validate/img816.jpg
# 32526
# Uploading file:processed/roses/validate/img590.jpg
# 15586
# Uploading file:processed/daisy/validate/img569.jpg
# 30378
# Uploading file:processed/sunflowers/validate/img384.jpg
# 34048
# Uploading file:processed/sunflowers/validate/img385.jpg
# 44095
# Uploading file:processed/sunflowers/validate/img386.jpg
# 20602
# Uploading file:processed/dandelion/validate/img817.jpg
# 20543
# Uploading file:processed/roses/validate/img591.jpg
# 12463
# Uploading file:processed/dandelion/validate/img818.jpg
# 10213
# Uploading file:processed/roses/validate/img592.jpg
# 16893
# Uploading file:processed/roses/validate/img593.jpg
# 16140
# Uploading file:processed/daisy/validate/img570.jpg
# 20357
# Uploading file:processed/daisy/validate/img571.jpg
# 9056
# Uploading file:processed/daisy/validate/img572.jpg
# 15904
# Uploading file:processed/dandelion/validate/img819.jpg
# 9471
# Uploading file:processed/dandelion/validate/img820.jpg
# 22482
# Uploading file:processed/sunflowers/validate/img387.jpg
# 23683
# Uploading file:processed/roses/validate/img594.jpg
# 26016
# Uploading file:processed/daisy/validate/img573.jpg
# 8470
# Uploading file:processed/roses/validate/img595.jpg
# 23120
# Uploading file:processed/daisy/validate/img574.jpg
# 11771
# Uploading file:processed/sunflowers/validate/img388.jpg
# 20145
# Uploading file:processed/sunflowers/validate/img389.jpg
# 30167
# Uploading file:processed/daisy/validate/img575.jpg
# 13089
# Uploading file:processed/dandelion/validate/img821.jpg
# 14392
# Uploading file:processed/dandelion/validate/img822.jpg
# 17100
# Uploading file:processed/daisy/validate/img576.jpg
# 32773
# Uploading file:processed/daisy/validate/img577.jpg
# 41199
# Uploading file:processed/daisy/validate/img578.jpg
# 12921
# Uploading file:processed/sunflowers/validate/img390.jpg
# 17137
# Uploading file:processed/dandelion/validate/img823.jpg
# 8537
# Uploading file:processed/sunflowers/validate/img391.jpg
# 32030
# Uploading file:processed/sunflowers/validate/img392.jpg
# 27642
# Uploading file:processed/roses/validate/img596.jpg
# 10788
# Uploading file:processed/roses/validate/img597.jpg
# 16414
# Uploading file:processed/daisy/validate/img579.jpg
# 12083
# Uploading file:processed/roses/validate/img598.jpg
# 8371
# Uploading file:processed/daisy/validate/img580.jpg
# 16754
# Uploading file:processed/dandelion/validate/img824.jpg
# 13847
# Uploading file:processed/dandelion/validate/img825.jpg
# 27657
# Uploading file:processed/dandelion/validate/img826.jpg
# 15712
# Uploading file:processed/dandelion/validate/img827.jpg
# 18555
# Uploading file:processed/dandelion/validate/img828.jpg
# 16981
# Uploading file:processed/roses/validate/img599.jpg
# 40377
# Uploading file:processed/dandelion/validate/img829.jpg
# 9514
# Uploading file:processed/daisy/validate/img581.jpg
# 17958
# Uploading file:processed/daisy/validate/img582.jpg
# 13806
# Uploading file:processed/dandelion/validate/img830.jpg
# 27100
# Uploading file:processed/dandelion/validate/img831.jpg
# 11968
# Uploading file:processed/roses/validate/img600.jpg
# 8579
# Uploading file:processed/roses/validate/img601.jpg
# 18985
# Uploading file:processed/daisy/validate/img583.jpg
# 26280
# Uploading file:processed/daisy/validate/img584.jpg
# 18124
# Uploading file:processed/dandelion/validate/img832.jpg
# 32658
# Uploading file:processed/sunflowers/validate/img393.jpg
# 27867
# Uploading file:processed/roses/validate/img602.jpg
# 15950
# Uploading file:processed/dandelion/validate/img833.jpg
# 27912
# Uploading file:processed/dandelion/validate/img834.jpg
# 10271
# Uploading file:processed/dandelion/validate/img835.jpg
# 16633
# Uploading file:processed/daisy/validate/img585.jpg
# 20377
# Uploading file:processed/sunflowers/validate/img394.jpg
# 24207
# Uploading file:processed/dandelion/validate/img836.jpg
# 8003
# Uploading file:processed/dandelion/validate/img837.jpg
# 17828
# Uploading file:processed/roses/validate/img603.jpg
# 17570
# Uploading file:processed/sunflowers/validate/img395.jpg
# 26776
# Uploading file:processed/dandelion/validate/img838.jpg
# 16785
# Uploading file:processed/dandelion/validate/img839.jpg
# 13776
# Uploading file:processed/sunflowers/validate/img396.jpg
# 23739
# Uploading file:processed/sunflowers/validate/img397.jpg
# 16852
# Uploading file:processed/daisy/validate/img586.jpg
# 8663
# Uploading file:processed/dandelion/validate/img840.jpg
# 24132
# Uploading file:processed/roses/validate/img604.jpg
# 37527
# Uploading file:processed/roses/validate/img605.jpg
# 14118
# Uploading file:processed/daisy/validate/img587.jpg
# 6410
# Uploading file:processed/sunflowers/validate/img398.jpg
# 27836
# Uploading file:processed/dandelion/validate/img841.jpg
# 19987
# Uploading file:processed/roses/validate/img606.jpg
# 22126
# Uploading file:processed/dandelion/validate/img842.jpg
# 16444
# Uploading file:processed/dandelion/validate/img843.jpg
# 16293
# Uploading file:processed/daisy/validate/img588.jpg
# 11573
# Uploading file:processed/daisy/validate/img589.jpg
# 18075
# Uploading file:processed/daisy/validate/img590.jpg
# 42959
# Uploading file:processed/daisy/validate/img591.jpg
# 12201
# Uploading file:processed/roses/validate/img607.jpg
# 26587
# Uploading file:processed/roses/validate/img608.jpg
# 27420
# Uploading file:processed/daisy/validate/img592.jpg
# 12480
# Uploading file:processed/daisy/validate/img593.jpg
# 15025
# Uploading file:processed/roses/validate/img609.jpg
# 15645
# Uploading file:processed/sunflowers/validate/img399.jpg
# 12137
# Uploading file:processed/dandelion/validate/img844.jpg
# 15276
# Uploading file:processed/daisy/validate/img594.jpg
# 10008
# Uploading file:processed/roses/validate/img610.jpg
# 11619
# Uploading file:processed/sunflowers/validate/img400.jpg
# 14038
# Uploading file:processed/roses/validate/img611.jpg
# 28942
# Uploading file:processed/dandelion/validate/img845.jpg
# 14160
# Uploading file:processed/dandelion/validate/img846.jpg
# 28390
# Uploading file:processed/dandelion/validate/img847.jpg
# 19528
# Uploading file:processed/sunflowers/validate/img401.jpg
# 19410
# Uploading file:processed/dandelion/validate/img848.jpg
# 20677
# Uploading file:processed/daisy/validate/img595.jpg
# 10500
# Uploading file:processed/sunflowers/validate/img402.jpg
# 23643
# Uploading file:processed/sunflowers/validate/img403.jpg
# 24805
# Uploading file:processed/roses/validate/img612.jpg
# 24193
# Uploading file:processed/roses/validate/img613.jpg
# 33237
# Uploading file:processed/roses/validate/img614.jpg
# 11426
# Uploading file:processed/roses/validate/img615.jpg
# 26481
# Uploading file:processed/roses/validate/img616.jpg
# 25842
# Uploading file:processed/dandelion/validate/img849.jpg
# 20058
# Uploading file:processed/roses/validate/img617.jpg
# 17373
# Uploading file:processed/sunflowers/validate/img404.jpg
# 18857
# Uploading file:processed/daisy/validate/img596.jpg
# 16788
# Uploading file:processed/roses/validate/img618.jpg
# 17016
# Uploading file:processed/sunflowers/validate/img405.jpg
# 20914
# Uploading file:processed/daisy/validate/img597.jpg
# 24027
# Uploading file:processed/dandelion/validate/img850.jpg
# 6704
# Uploading file:processed/daisy/validate/img598.jpg
# 13897
# Uploading file:processed/roses/validate/img619.jpg
# 14718
# Uploading file:processed/sunflowers/validate/img406.jpg
# 33292
# Uploading file:processed/dandelion/validate/img851.jpg
# 7518
# Uploading file:processed/roses/validate/img620.jpg
# 26393
# Uploading file:processed/dandelion/validate/img852.jpg
# 21988
# Uploading file:processed/sunflowers/validate/img407.jpg
# 46094
# Uploading file:processed/dandelion/validate/img853.jpg
# 8799
# Uploading file:processed/dandelion/validate/img854.jpg
# 16859
# Uploading file:processed/dandelion/validate/img855.jpg
# 20885
# Uploading file:processed/daisy/validate/img599.jpg
# 21440
# Uploading file:processed/dandelion/validate/img856.jpg
# 15739
# Uploading file:processed/sunflowers/validate/img408.jpg
# 22052
# Uploading file:processed/daisy/validate/img600.jpg
# 12071
# Uploading file:processed/roses/validate/img621.jpg
# 18423
# Uploading file:processed/dandelion/validate/img857.jpg
# 25326
# Uploading file:processed/sunflowers/validate/img409.jpg
# 17753
# Uploading file:processed/sunflowers/validate/img410.jpg
# 20820
# Uploading file:processed/roses/validate/img622.jpg
# 9004
# Uploading file:processed/dandelion/validate/img858.jpg
# 12751
# Uploading file:processed/dandelion/validate/img859.jpg
# 16964
# Uploading file:processed/dandelion/validate/img860.jpg
# 13356
# Uploading file:processed/daisy/validate/img601.jpg
# 15767
# Uploading file:processed/roses/validate/img623.jpg
# 16793
# Uploading file:processed/daisy/validate/img602.jpg
# 11906
# Uploading file:processed/daisy/validate/img603.jpg
# 24788
# Uploading file:processed/dandelion/validate/img861.jpg
# 33192
# Uploading file:processed/daisy/validate/img604.jpg
# 26970
# Uploading file:processed/dandelion/validate/img862.jpg
# 5615
# Uploading file:processed/dandelion/validate/img863.jpg
# 15079
# Uploading file:processed/daisy/validate/img605.jpg
# 22246
# Uploading file:processed/dandelion/validate/img864.jpg
# 10276
# Uploading file:processed/sunflowers/validate/img411.jpg
# 31957
# Uploading file:processed/roses/validate/img624.jpg
# 19614
# Uploading file:processed/roses/validate/img625.jpg
# 14642
# Uploading file:processed/sunflowers/validate/img412.jpg
# 19531
# Uploading file:processed/roses/validate/img626.jpg
# 35720
# Uploading file:processed/roses/validate/img627.jpg
# 11074
# Uploading file:processed/roses/validate/img628.jpg
# 18028
# Uploading file:processed/dandelion/validate/img865.jpg
# 21060
# Uploading file:processed/daisy/validate/img606.jpg
# 12268
# Uploading file:processed/dandelion/validate/img866.jpg
# 12057
# Uploading file:processed/dandelion/validate/img867.jpg
# 4663
# Uploading file:processed/dandelion/validate/img868.jpg
# 25906
# Uploading file:processed/sunflowers/validate/img413.jpg
# 23122
# Uploading file:processed/daisy/validate/img607.jpg
# 8351
# Uploading file:processed/sunflowers/validate/img414.jpg
# 33901
# Uploading file:processed/daisy/validate/img608.jpg
# 13952
# Uploading file:processed/dandelion/validate/img869.jpg
# 12770
# Uploading file:processed/sunflowers/validate/img415.jpg
# 28021
# Uploading file:processed/dandelion/validate/img870.jpg
# 12929
# Uploading file:processed/roses/validate/img629.jpg
# 8623
# Uploading file:processed/daisy/validate/img609.jpg
# 14035
# Uploading file:processed/daisy/validate/img610.jpg
# 13122
# Uploading file:processed/daisy/validate/img611.jpg
# 18494
# Uploading file:processed/dandelion/validate/img871.jpg
# 15783
# Uploading file:processed/dandelion/validate/img872.jpg
# 15177
# Uploading file:processed/dandelion/validate/img873.jpg
# 11990
# Uploading file:processed/daisy/validate/img612.jpg
# 13601
# Uploading file:processed/daisy/validate/img613.jpg
# 10169
# Uploading file:processed/roses/validate/img630.jpg
# 18722
# Uploading file:processed/dandelion/validate/img874.jpg
# 35136
# Uploading file:processed/dandelion/validate/img875.jpg
# 11395
# Uploading file:processed/dandelion/validate/img876.jpg
# 18172
# Uploading file:processed/sunflowers/validate/img416.jpg
# 22837
# Uploading file:processed/daisy/validate/img614.jpg
# 11391
# Uploading file:processed/daisy/validate/img615.jpg
# 15534
# Uploading file:processed/daisy/validate/img616.jpg
# 19644
# Uploading file:processed/dandelion/validate/img877.jpg
# 28531
# Uploading file:processed/daisy/validate/img617.jpg
# 24001
# Uploading file:processed/dandelion/validate/img878.jpg
# 12411
# Uploading file:processed/sunflowers/validate/img417.jpg
# 28375
# Uploading file:processed/daisy/validate/img618.jpg
# 13721
# Uploading file:processed/dandelion/validate/img879.jpg
# 15060
# Uploading file:processed/daisy/validate/img619.jpg
# 9821
# Uploading file:processed/roses/validate/img631.jpg
# 14734
# Uploading file:processed/dandelion/validate/img880.jpg
# 14713
# Uploading file:processed/daisy/validate/img620.jpg
# 17690
# Uploading file:processed/daisy/validate/img621.jpg
# 14667
# Uploading file:processed/dandelion/validate/img881.jpg
# 24126
# Uploading file:processed/dandelion/validate/img882.jpg
# 9896
# Uploading file:processed/dandelion/validate/img883.jpg
# 27602
# Uploading file:processed/roses/validate/img632.jpg
# 33041
# Uploading file:processed/dandelion/validate/img884.jpg
# 16904
# Uploading file:processed/sunflowers/validate/img418.jpg
# 15618
# Uploading file:processed/dandelion/validate/img885.jpg
# 17402
# Uploading file:processed/dandelion/validate/img886.jpg
# 21599
# Uploading file:processed/dandelion/validate/img887.jpg
# 26800
# Uploading file:processed/dandelion/validate/img888.jpg
# 22150
# Uploading file:processed/dandelion/validate/img889.jpg
# 14464
# Uploading file:processed/daisy/validate/img622.jpg
# 27040
# Uploading file:processed/daisy/validate/img623.jpg
# 14526
# Uploading file:processed/dandelion/validate/img890.jpg
# 11393
# Uploading file:processed/dandelion/validate/img891.jpg
# 13956
# Uploading file:processed/roses/validate/img633.jpg
# 28866
# Uploading file:processed/roses/validate/img634.jpg
# 14178
# Uploading file:processed/roses/validate/img635.jpg
# 32661
# Uploading file:processed/daisy/validate/img624.jpg
# 16986
# Uploading file:processed/roses/validate/img636.jpg
# 23046
# Uploading file:processed/roses/validate/img637.jpg
# 12986
# Uploading file:processed/sunflowers/validate/img419.jpg
# 36842
# Uploading file:processed/roses/validate/img638.jpg
# 9036
# Uploading file:processed/dandelion/validate/img892.jpg
# 15118
# Uploading file:processed/sunflowers/validate/img420.jpg
# 24556
# Uploading file:processed/daisy/validate/img625.jpg
# 17859
# Uploading file:processed/daisy/validate/img626.jpg
# 15759
# Uploading file:processed/dandelion/validate/img893.jpg
# 12187
# Uploading file:processed/dandelion/validate/img894.jpg
# 19154
# Uploading file:processed/dandelion/validate/img895.jpg
# 12595
# Uploading file:processed/daisy/validate/img627.jpg
# 13007
# Uploading file:processed/roses/validate/img639.jpg
# 13610
# Uploading file:processed/sunflowers/validate/img421.jpg
# 30836
# Uploading file:processed/daisy/validate/img628.jpg
# 21523
# Uploading file:processed/daisy/validate/img629.jpg
# 10028
# Uploading file:processed/sunflowers/validate/img422.jpg
# 27115
# Uploading file:processed/roses/validate/img640.jpg
# 18265
# Uploading file:processed/dandelion/validate/img896.jpg
# 18516
# Uploading file:processed/daisy/validate/img630.jpg
# 16943
# Uploading file:processed/sunflowers/validate/img423.jpg
# 19506
# Uploading file:processed/daisy/validate/img631.jpg
# 17394
# Uploading file:processed/daisy/validate/img632.jpg
# 26645
# Uploading file:processed/dandelion/validate/img897.jpg
# 13156
# Uploading file:processed/sunflowers/validate/img424.jpg
# 25676
# Uploading file:processed/daisy/validate/img633.jpg
# 23347
# Uploading file:processed/dandelion/validate/img898.jpg
# 22637
# Uploading file:processed/daisy/validate/img634.jpg
# 15798
# Uploading file:processed/roses/validate/img641.jpg
# 21252
